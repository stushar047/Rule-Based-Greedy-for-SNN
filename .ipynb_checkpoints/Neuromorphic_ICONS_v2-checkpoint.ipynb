# %%
import numpy as np

import matplotlib.pyplot as plt

from sklearn.datasets import load_iris,load_diabetes, load_breast_cancer

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split

from mravens_icons import *

import tensorflow as tf

from tensorflow.keras import Sequential

from tensorflow.keras.layers import Dense

# %%
def one_hot(y):
    
    y_onehot = np.zeros((len(y),3))

    for i,j in enumerate(y):

        y_onehot[i,j]=1
        
    return y_onehot

# %%
data=load_iris()

X,y=data['data'],data['target']

y_onehot = one_hot(y)

X_norm=(X-np.min(X,axis=0))/(np.max(X,axis=0)-np.min(X,axis=0))

f_sample=32

# %%
X_train,X_test,y_train,y_test = train_test_split(X_norm,y_onehot,test_size=0.20,random_state=42, stratify=y)

# %%
X_rate_train,X_rate_test = (X_train*f_sample).astype('int'), (X_test*f_sample).astype('int')

# %%
# Define the input shape
input_shape = (X_norm.shape[1],)  # Replace input_size with the size of your input

# Create a Sequential model
model = Sequential()

initializer = tf.keras.initializers.HeNormal()

# Add the output layer directly
model.add(Dense(units=y_onehot.shape[1], input_shape=input_shape, activation='softmax',use_bias=False, kernel_initializer=initializer))

opt = tf.keras.optimizers.Adam(learning_rate=0.1,beta_1=0.7,beta_2=0.999)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Print a summary of the model
model.summary()
# Out:
# Model: "sequential_19"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_19 (Dense)            (None, 3)                 12
#
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_train, y_train, epochs=200, batch_size=64, verbose=1, validation_data=(X_test,y_test),shuffle=True)
# Out:
# Epoch 1/200
# 2/2 [==============================] - 1s 200ms/step - loss: 1.1255 - accuracy: 0.2917 - val_loss: 0.9918 - val_accuracy: 0.5333
# Epoch 2/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.9709 - accuracy: 0.5750 - val_loss: 0.8845 - val_accuracy: 0.6333
# Epoch 3/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.8730 - accuracy: 0.6250 - val_loss: 0.8119 - val_accuracy: 0.6667
# Epoch 4/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.8062 - accuracy: 0.6667 - val_loss: 0.7594 - val_accuracy: 0.6667
# Epoch 5/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.7562 - accuracy: 0.6583 - val_loss: 0.7160 - val_accuracy: 0.6667
# Epoch 6/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.7145 - accuracy: 0.6583 - val_loss: 0.6806 - val_accuracy: 0.6667
# Epoch 7/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.6843 - accuracy: 0.6667 - val_loss: 0.6532 - val_accuracy: 0.6667
# Epoch 8/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6577 - accuracy: 0.6833 - val_loss: 0.6305 - val_accuracy: 0.6667
# Epoch 9/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.6357 - accuracy: 0.6833 - val_loss: 0.6123 - val_accuracy: 0.6667
# Epoch 10/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.6220 - accuracy: 0.6667 - val_loss: 0.5977 - val_accuracy: 0.6667
# Epoch 11/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.6073 - accuracy: 0.6667 - val_loss: 0.5819 - val_accuracy: 0.6667
# Epoch 12/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.5904 - accuracy: 0.6750 - val_loss: 0.5702 - val_accuracy: 0.6667
# Epoch 13/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5783 - accuracy: 0.6667 - val_loss: 0.5616 - val_accuracy: 0.6667
# Epoch 14/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5682 - accuracy: 0.6667 - val_loss: 0.5508 - val_accuracy: 0.6667
# Epoch 15/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5594 - accuracy: 0.6667 - val_loss: 0.5415 - val_accuracy: 0.6667
# Epoch 16/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5518 - accuracy: 0.6667 - val_loss: 0.5342 - val_accuracy: 0.6667
# Epoch 17/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.5465 - accuracy: 0.6750 - val_loss: 0.5268 - val_accuracy: 0.6667
# Epoch 18/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.5391 - accuracy: 0.6667 - val_loss: 0.5221 - val_accuracy: 0.6667
# Epoch 19/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.
200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3984 - accuracy: 0.8000 - val_loss: 0.3822 - val_accuracy: 0.8333
# Epoch 144/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3989 - accuracy: 0.7833 - val_loss: 0.3822 - val_accuracy: 0.8333
# Epoch 145/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.4004 - accuracy: 0.8000 - val_loss: 0.3820 - val_accuracy: 0.8333
# Epoch 146/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4001 - accuracy: 0.7833 - val_loss: 0.3825 - val_accuracy: 0.7667
# Epoch 147/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.4007 - accuracy: 0.7750 - val_loss: 0.3815 - val_accuracy: 0.8333
# Epoch 148/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.4006 - accuracy: 0.7917 - val_loss: 0.3814 - val_accuracy: 0.8333
# Epoch 149/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3962 - accuracy: 0.7917 - val_loss: 0.3828 - val_accuracy: 0.7667
# Epoch 150/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3982 - accuracy: 0.7667 - val_loss: 0.3817 - val_accuracy: 0.8000
# Epoch 151/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3959 - accuracy: 0.8000 - val_loss: 0.3812 - val_accuracy: 0.8000
# Epoch 152/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.3981 - accuracy: 0.8167 - val_loss: 0.3810 - val_accuracy: 0.8000
# Epoch 153/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3953 - accuracy: 0.7833 - val_loss: 0.3814 - val_accuracy: 0.8000
# Epoch 154/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3984 - accuracy: 0.7667 - val_loss: 0.3809 - val_accuracy: 0.8333
# Epoch 155/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3948 - accuracy: 0.7917 - val_loss: 0.3808 - val_accuracy: 0.8000
# Epoch 156/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3952 - accuracy: 0.8083 - val_loss: 0.3810 - val_accuracy: 0.8000
# Epoch 157/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3992 - accuracy: 0.8167 - val_loss: 0.3799 - val_accuracy: 0.8333
# Epoch 158/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3965 - accuracy: 0.7917 - val_loss: 0.3822 - val_accuracy: 0.7667
# Epoch 159/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3981 - accuracy: 0.7500 - val_loss: 0.3797 - val_accuracy: 0.8333
# Epoch 160/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3944 - accuracy: 0.7833 - val_loss: 0.3815 - val_accuracy: 0.8000
# Epoch 161/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3969 - accuracy: 0.8250 - val_loss: 0.3794 - val_accuracy: 0.8000
# Epoch 162/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3929 - accuracy: 0.7833 - val_loss: 0.3807 - val_accuracy: 0.7667
# Epoch 163/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3948 - accuracy: 0.7667 - val_loss: 0.3795 - val_accuracy: 0.8000
# Epoch 164/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3984 - accuracy: 0.8000 - val_loss: 0.3794 - val_accuracy: 0.8000
# Epoch 165/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.3933 - accuracy: 0.8083 - val_loss: 0.3789 - val_accuracy: 0.8333
# Epoch 166/200
# 2/2 [==============================] - 0s 21ms/step - loss: 0.3928 - accuracy: 0.7917 - val_loss: 0.3797 - val_accuracy: 0.8000
# Epoch 167/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.3944 - accuracy: 0.8000 - val_loss: 0.3793 - val_accuracy: 0.8000
# Epoch 168/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3923 - accuracy: 0.7833 - val_loss: 0.3788 - val_accuracy: 0.8000
# Epoch 169/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3920 - accuracy: 0.7833 - val_loss: 0.3783 - val_accuracy: 0.8333
# Epoch 170/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3952 - accuracy: 0.8000 - val_loss: 0.3789 - val_accuracy: 0.8000
# Epoch 171/200
# 2/2 [==============================] - 0s 22ms/step - loss: 0.3977 - accuracy: 0.8167 - val_loss: 0.3786 - val_accuracy: 0.8000
# Epoch 172/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3956 - accuracy: 0.7917 - val_loss: 0.3779 - val_accuracy: 0.8000
# Epoch 173/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3957 - accuracy: 0.7833 - val_loss: 0.3780 - val_accuracy: 0.8000
# Epoch 174/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.3918 - accuracy: 0.7833 - val_loss: 0.3778 - val_accuracy: 0.8000
# Epoch 175/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.3920 - accuracy: 0.8167 - val_loss: 0.3774 - val_accuracy: 0.8000
# Epoch 176/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.3894 - accuracy: 0.8000 - val_loss: 0.3782 - val_accuracy: 0.8000
# Epoch 177/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3916 - accuracy: 0.7833 - val_loss: 0.3778 - val_accuracy: 0.8000
# Epoch 178/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3891 - accuracy: 0.8000 - val_loss: 0.3777 - val_accuracy: 0.8000
# Epoch 179/200
# 2/2 [==============================] - 0s 25ms/step - loss: 0.3896 - accuracy: 0.8167 - val_loss: 0.3776 - val_accuracy: 0.8000
# Epoch 180/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.3906 - accuracy: 0.8167 - val_loss: 0.3772 - val_accuracy: 0.8333
# Epoch 181/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3889 - accuracy: 0.7917 - val_loss: 0.3771 - val_accuracy: 0.8000
# Epoch 182/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3885 - accuracy: 0.7917 - val_loss: 0.3770 - val_accuracy: 0.8333
# Epoch 183/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3913 - accuracy: 0.8000 - val_loss: 0.3767 - val_accuracy: 0.8333
# Epoch 184/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.3884 - accuracy: 0.7917 - val_loss: 0.3772 - val_accuracy: 0.8000
# Epoch 185/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.3919 - accuracy: 0.7500 - val_loss: 0.3775 - val_accuracy: 0.8000
# Epoch 186/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3897 - accuracy: 0.8083 - val_loss: 0.3773 - val_accuracy: 0.8333
# Epoch 187/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3887 - accuracy: 0.8167 - val_loss: 0.3767 - val_accuracy: 0.8000
# Epoch 188/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3871 - accuracy: 0.8000 - val_loss: 0.3770 - val_accuracy: 0.8000
# Epoch 189/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3884 - accuracy: 0.7833 - val_loss: 0.3766 - val_accuracy: 0.8000
# Epoch 190/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3885 - accuracy: 0.7917 - val_loss: 0.3764 - val_accuracy: 0.8000
# Epoch 191/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3868 - accuracy: 0.7917 - val_loss: 0.3765 - val_accuracy: 0.8333
# Epoch 192/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.3909 - accuracy: 0.8417 - val_loss: 0.3769 - val_accuracy: 0.8333
# Epoch 193/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.3863 - accuracy: 0.8000 - val_loss: 0.3764 - val_accuracy: 0.8000
# Epoch 194/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.3873 - accuracy: 0.7833 - val_loss: 0.3768 - val_accuracy: 0.8000
# Epoch 195/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.3869 - accuracy: 0.7833 - val_loss: 0.3759 - val_accuracy: 0.8000
# Epoch 196/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.3884 - accuracy: 0.8167 - val_loss: 0.3769 - val_accuracy: 0.8333
# Epoch 197/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.3870 - accuracy: 0.8083 - val_loss: 0.3760 - val_accuracy: 0.8000
# Epoch 198/200
# 2/2 [==============================] - 0s 23ms/step - loss: 0.3855 - accuracy: 0.7917 - val_loss: 0.3758 - val_accuracy: 0.8333
# Epoch 199/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.3853 - accuracy: 0.7917 - val_loss: 0.3757 - val_accuracy: 0.8000
# Epoch 200/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.3854 - accuracy: 0.7917 - val_loss: 0.3757 - val_accuracy: 0.8333

# %%
keras_loss_train, keras_acc_train = model.evaluate(X_train, y_train, verbose=0)

keras_loss_test, keras_acc_test= model.evaluate(X_test, y_test, verbose=0)

keras_weights = model.get_weights()[0]

# %%
X_rate_data_train=np.zeros((X_rate_train.shape[0],X_rate_train.shape[1],f_sample))

for m,sample in enumerate(X_rate_train):
    
    for n,feature in enumerate(sample):
        
        X_rate_data_train[m,n,:]=np.zeros(f_sample)
        
        if feature>0:
        
            X_rate_data_train[m,n,0:-1:round(f_sample/feature)]=1

# %%
X_rate_data_test=np.zeros((X_rate_test.shape[0],X_rate_test.shape[1],f_sample))

for m,sample in enumerate(X_rate_test):
    
    for n,feature in enumerate(sample):
        
        X_rate_data_test[m,n,:]=np.zeros(f_sample)
        
        if feature>0:
        
            X_rate_data_test[m,n,0:-1:round(f_sample/feature)]=1

# %%
def simulate(X_rate_data,keras_weights,f_sample,st_point=[0,1,2,3],n_id =[0,1,2],
                  type_id=["output","output","output"],abs_period=[1,10,1]):

    y_pred = []

    for i in range(len(X_rate_data)):

        net = create_custom_network()

        net.add_stimuli(st_point,n_id,X_rate_data[i],keras_weights)

        for (i,j,k) in zip(n_id,type_id,abs_period):

            net.add_neuron(i,j)
            
            net.neuron[i].abs_period=k

        proc=MRAVENS(-5,5)

        event=process_event(f_sample,net,proc)

        event.apply_spike()

        y_pred.append(np.argmax(np.sum(event.spikes_,axis=0)))
        
    return np.array(y_pred)

# %%
ytrain = np.argmax(y_train,axis=1)

ytest = np.argmax(y_test,axis=1)

# %%
abs_period = np.array([10,10,10])

acc_train_list, acc_test_list, abs_period_list = [], [], []

for i in range(20):

    y_pred_train = simulate(X_rate_data_train,keras_weights,f_sample,st_point=[0,1,2,3],n_id =[0,1,2],type_id=["output","output","output"],abs_period=abs_period)

    y_pred_test = simulate(X_rate_data_test,keras_weights,f_sample,st_point=[0,1,2,3],n_id =[0,1,2],type_id=["output","output","output"],abs_period=abs_period)

    acc_train, acc_test = len(ytrain[y_pred_train==ytrain])/len(ytrain), len(ytest[y_pred_test==ytest])/len(y_test)

    print(f"Iteration:{i}, Keras Accuracy: {keras_acc_train, keras_acc_test} ::: Neuromorphic Accuracy: {acc_train,acc_test}")
    
    spike_dev = np.sum(one_hot(y_pred_train)-y_train,axis=0)
    
    print(spike_dev)

    spike_dev_arr = np.zeros_like(spike_dev)
    
    idx = np.argsort(spike_dev)

    spike_dev_arr[idx[0]], spike_dev_arr[idx[1]]= -1, 0 

    abs_period = (abs_period + spike_dev_arr).astype('int')
    
    acc_train_list.append(acc_train)
    
    acc_test_list.append(acc_test)
    
    abs_period_list.append(abs_period)
    
    print(abs_period)
# Out:
# Iteration:0, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.65, 0.6666666666666666)
# [  2.  38. -40.]
# [10 10  9]
# Iteration:1, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.65, 0.6666666666666666)
# [  2.  38. -40.]
# [10 10  8]
# Iteration:2, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.725, 0.7666666666666667)
# [  2. -33.  31.]
# [10  9  8]
# Iteration:3, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.725, 0.7666666666666667)
# [  2. -33.  31.]
# [10  8  8]
# Iteration:4, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.675, 0.7333333333333333)
# [  0.  35. -35.]
# [10  8  7]
# Iteration:5, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.675, 0.6666666666666666)
# [  0.  35. -35.]
# [10  8  6]
# Iteration:6, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.6666666666666666, 0.6666666666666666)
# [ -1.  35. -34.]
# [10  8  5]
# Iteration:7, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.875, 0.8666666666666667)
# [-2. -7.  9.]
# [10  7  5]
# Iteration:8, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.8833333333333333, 0.9)
# [-2. -6.  8.]
# [10  6  5]
# Iteration:9, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.875, 0.9)
# [-3. -5.  8.]
# [10  5  5]
# Iteration:10, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.6083333333333333, 0.6666666666666666)
# [ -3.  27. -24.]
# [10  5  4]
# Iteration:11, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.6416666666666667, 0.6666666666666666)
# [ -3. -39.  42.]
# [10  4  4]
# Iteration:12, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.6416666666666667, 0.7333333333333333)
# [ -3.  37. -34.]
# [10  4  3]
# Iteration:13, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.8833333333333333, 0.8666666666666667)
# [-3.  4. -1.]
# [9 4 3]
# Iteration:14, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.8833333333333333, 0.8666666666666667)
# [-3.  4. -1.]
# [8 4 3]
# Iteration:15, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.8833333333333333, 0.8666666666666667)
# [-3.  4. -1.]
# [7 4 3]
# Iteration:16, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.8833333333333333, 0.8666666666666667)
# [-3.  4. -1.]
# [6 4 3]
# Iteration:17, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.9, 0.8666666666666667)
# [-1.  3. -2.]
# [6 4 2]
# Iteration:18, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.7083333333333334, 0.6666666666666666)
# [ -1. -34.  35.]
# [6 3 2]
# Iteration:19, Keras Accuracy: (0.8083333373069763, 0.8333333134651184) ::: Neuromorphic Accuracy: (0.7083333333333334, 0.7333333333333333)
# [ -1. -34.  35.]
# [6 2 2]

# %%
# abs_period = np.array([1,1,1])

# for i in range(40):

#     y_pred_train = simulate(X_rate_data_train,keras_weights,f_sample,st_point=[0,1,2,3],n_id =[0,1,2],type_id=["output","output","output"],abs_period=abs_period)

#     y_pred_test = simulate(X_rate_data_test,keras_weights,f_sample,st_point=[0,1,2,3],n_id =[0,1,2],type_id=["output","output","output"],abs_period=abs_period)

#     acc_train, acc_test = len(ytrain[y_pred_train==ytrain])/len(ytrain), len(ytest[y_pred_test==ytest])/len(y_test)

#     print(f"Iteration:{i}, Keras Accuracy: {keras_acc_train, keras_acc_test} ::: Neuromorphic Accuracy: {acc_train,acc_test}")
    
#     spike_dev = np.sum(one_hot(y_pred_train)-y_train,axis=0)
    
#     print(spike_dev)

#     spike_dev_arr = np.zeros_like(spike_dev)
    
#     idx = np.argsort(spike_dev)

#     spike_dev_arr[idx[0]], spike_dev_arr[idx[1]]= 0, 1 

#     abs_period = (abs_period + spike_dev_arr).astype('int')
    
#     print(abs_period)

# %%
acc = len(y[y_pred==y])/len(y)

print(f"Keras Accuracy: {keras_acc} ::: Neuromorphic Accuracy: {acc}")
# Out:
# Keras Accuracy: 0.8199999928474426 ::: Neuromorphic Accuracy: 0.9

# %%
sublist = np.array(abs_period_list)

xticks_labels =[]

for item in sublist:
    
    xticks_labels.append(f"{item[0]},{item[1]},{item[2]}")

plt.figure(figsize=(20,6))

plt.rcParams.update({'font.size': 14})

plt.plot(acc_test_list, linewidth = 4)

plt.plot(acc_train_list,linewidth = 4)

plt.xticks(range(len(xticks_labels)), xticks_labels)

plt.legend(["train_accuracy","test_accuracy"])

plt.xlabel("Absoluate Period: (Neuron 1, Neuron 2, Neuron 3)")

plt.ylabel("Accuracy")

plt.title(f"Dataset(Iris), Software accuracy: Train:{keras_acc_train}, Test:{keras_acc_test}")

plt.savefig("Iris_abs.jpg",dpi=600,bbox_inches='tight')

plt.show()
