# %%
import numpy as np

import matplotlib.pyplot as plt

from sklearn.datasets import load_iris

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split

from mravens_icons import *

import tensorflow as tf

from tensorflow.keras import Sequential

from tensorflow.keras.layers import Dense

# %%
data=load_iris()

X,y=data['data'],data['target']

y_onehot = np.zeros((len(y),np.max(y)+1))

for i,j in enumerate(y):
    
    y_onehot[i,j]=1

X_norm=(X-np.min(X,axis=0))/(np.max(X,axis=0)-np.min(X,axis=0))

f_sample=32

X_rate=(X_norm*f_sample).astype('int')

# %%
def one_hot(y):
    
    y_onehot = np.zeros((len(y),np.max(y)+1))

    for i,j in enumerate(y):

        y_onehot[i,j]=1
        
    return y_onehot

# %%
y_onehot = one_hot(y)

# %%
# y_onehot = np.zeros((len(y),np.max(y)+1))

# for i,j in enumerate(y):
    
#     y_onehot[i,j]=1

# %%
# X_train, X_test, y_train, y_test = train_test_split(X_norm,y_onehot, test_size=0.05, random_state=42)

# %%
# Define the input shape
input_shape = (X_norm.shape[1],)  # Replace input_size with the size of your input

# Create a Sequential model
model = Sequential()

initializer = tf.keras.initializers.HeNormal()

# Add the output layer directly
model.add(Dense(units=y_onehot.shape[1], input_shape=input_shape, activation='softmax',use_bias=False, kernel_initializer=initializer))

opt = tf.keras.optimizers.Adam(learning_rate=0.1,beta_1=0.8,beta_2=0.999)

model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])

# Print a summary of the model
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_7 (Dense)             (None, 3)                 12
#
# =================================================================
# Total params: 12
# Trainable params: 12
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Train the model
history = model.fit(X_norm, y_onehot, epochs=200, batch_size=32, verbose=1)
# Out:
# Epoch 1/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.9704 - accuracy: 0.6600
# Epoch 2/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.7861 - accuracy: 0.6667
# Epoch 3/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.6905 - accuracy: 0.6667
# Epoch 4/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.6322 - accuracy: 0.6667
# Epoch 5/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.6013 - accuracy: 0.6800
# Epoch 6/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5710 - accuracy: 0.6667
# Epoch 7/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.5394 - accuracy: 0.6733
# Epoch 8/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.5258 - accuracy: 0.6933
# Epoch 9/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.5149 - accuracy: 0.6667
# Epoch 10/200
# 5/5 [==============================] - 0s 253us/step - loss: 0.5031 - accuracy: 0.7000
# Epoch 11/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4978 - accuracy: 0.6667
# Epoch 12/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4975 - accuracy: 0.7133
# Epoch 13/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4786 - accuracy: 0.6600
# Epoch 14/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4730 - accuracy: 0.6800
# Epoch 15/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4699 - accuracy: 0.6800
# Epoch 16/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4705 - accuracy: 0.6733
# Epoch 17/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4705 - accuracy: 0.7600
# Epoch 18/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4798 - accuracy: 0.6800
# Epoch 19/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4502 - accuracy: 0.7600
# Epoch 20/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4567 - accuracy: 0.8067
# Epoch 21/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4698 - accuracy: 0.6667
# Epoch 22/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4510 - accuracy: 0.7800
# Epoch 23/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4489 - accuracy: 0.7933
# Epoch 24/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4623 - accuracy: 0.6733
# Epoch 25/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4443 - accuracy: 0.7800
# Epoch 26/200
# 5/5 [==============================] - 0s 717us/step - loss: 0.4423 - accuracy: 0.7733
# Epoch 27/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4326 - accuracy: 0.7467
# Epoch 28/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4347 - accuracy: 0.7600
# Epoch 29/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4375 - accuracy: 0.8067
# Epoch 30/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4315 - accuracy: 0.7400
# Epoch 31/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4332 - accuracy: 0.6867
# Epoch 32/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4231 - accuracy: 0.7867
# Epoch 33/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4294 - accuracy: 0.8467
# Epoch 34/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4424 - accuracy: 0.6733
# Epoch 35/200
# 5/5 [==============================] - 0s 130us/step - loss: 0.4270 - accuracy: 0.7800
# Epoch 36/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4281 - accuracy: 0.8000
# Epoch 37/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4199 - accuracy: 0.7467
# Epoch 38/200
# 5/5 [==============================] - 0s 434us/step - loss: 0.4202 - accuracy: 0.7733
# Epoch 39/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4189 - accuracy: 0.7933
# Epoch 40/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4181 - accuracy: 0.7933
# Epoch 41/200
# 5/5 [==============================] - 0s 41us/step - loss: 0.4150 - accuracy: 0.7533
# Epoch 42/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4148 - accuracy: 0.7533
# Epoch 43/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4145 - accuracy: 0.8000
# Epoch 44/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4137 - accuracy: 0.7933
# Epoch 45/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4144 - accuracy: 0.7733
# Epoch 46/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4138 - accuracy: 0.8133
# Epoch 47/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4202 - accuracy: 0.7467
# Epoch 48/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4097 - accuracy: 0.8000
# Epoch 49/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4095 - accuracy: 0.8267
# Epoch 50/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4119 - accuracy: 0.7333
# Epoch 51/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4070 - accuracy: 0.8267
# Epoch 52/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4081 - accuracy: 0.7800
# Epoch 53/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4063 - accuracy: 0.7800
# Epoch 54/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4054 - accuracy: 0.7867
# Epoch 55/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.4112 - accuracy: 0.8133
# Epoch 56/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4062 - accuracy: 0.7533
# Epoch 57/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.4082 - accuracy: 0.7667
# Epoch 58/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4060 - accuracy: 0.8067
# Epoch 59/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4032 - accuracy: 0.8000
# Epoch 60/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4013 - accuracy: 0.7800
# Epoch 61/200
# 5/5 [==============================] - 0s 827us/step - loss: 0.3992 - accuracy: 0.7867
# Epoch 62/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4028 - accuracy: 0.7933
# Epoch 63/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3996 - accuracy: 0.7800
# Epoch 64/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4001 - accuracy: 0.7667
# Epoch 65/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4008 - accuracy: 0.8000
# Epoch 66/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3969 - accuracy: 0.8067
# Epoch 67/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3975 - accuracy: 0.7867
# Epoch 68/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4000 - accuracy: 0.7800
# Epoch 69/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.4025 - accuracy: 0.8267
# Epoch 70/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.4071 - accuracy: 0.7933
# Epoch 71/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3925 - accuracy: 0.8133
# Epoch 72/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3971 - accuracy: 0.8200
# Epoch 73/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3935 - accuracy: 0.7867
# Epoch 74/200
# 5/5 [==============================] - 0s 6ms/step - loss: 0.3982 - accuracy: 0.7867
# Epoch 75/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3987 - accuracy: 0.8267
# Epoch 76/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.4001 - accuracy: 0.8000
# Epoch 77/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3904 - accuracy: 0.8067
# Epoch 78/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3941 - accuracy: 0.8400
# Epoch 79/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3940 - accuracy: 0.7867
# Epoch 80/200
# 5/5 [==============================] - 0s 943us/step - loss: 0.3935 - accuracy: 0.7800
# Epoch 81/200
# 5/5 [==============================] - 0s 1ms/step - loss: 0.3910 - accuracy: 0.8133
# Epoch 82/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3921 - accuracy: 0.7867
# Epoch 83/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3916 - accuracy: 0.8200
# Epoch 84/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3914 - accuracy: 0.7933
# Epoch 85/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3920 - accuracy: 0.7933
# Epoch 86/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3924 - accuracy: 0.7800
# Epoch 87/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3884 - accuracy: 0.7933
# Epoch 88/200
# 5/5 [==============================] - 0s 663us/step - loss: 0.3960 - accuracy: 0.7733
# Epoch 89/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3876 - accuracy: 0.8267
# Epoch 90/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3944 - accuracy: 0.8133
# Epoch 91/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3934 - accuracy: 0.8067
# Epoch 92/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3915 - accuracy: 0.7667
# Epoch 93/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3877 - accuracy: 0.8200
# Epoch 94/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3951 - accuracy: 0.7800
# Epoch 95/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3883 - accuracy: 0.8000
# Epoch 96/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3902 - accuracy: 0.8067
# Epoch 97/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3869 - accuracy: 0.7800
# Epoch 98/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3962 - accuracy: 0.7867
# Epoch 99/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3916 - accuracy: 0.7600
# Epoch 100/200
# 5/5 [==============================] - 0s 186us/step - loss: 0.3880 - accuracy: 0.7933
# Epoch 101/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3859 - accuracy: 0.8067
# Epoch 102/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3862 - accuracy: 0.7800
# Epoch 103/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3893 - accuracy: 0.7867
# Epoch 104/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3871 - accuracy: 0.7933
# Epoch 105/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3865 - accuracy: 0.8067
# Epoch 106/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3901 - accuracy: 0.8000
# Epoch 107/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3832 - accuracy: 0.8000
# Epoch 108/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3890 - accuracy: 0.7933
# Epoch 109/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3838 - accuracy: 0.8333
# Epoch 110/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3859 - accuracy: 0.7867
# Epoch 111/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3815 - accuracy: 0.7867
# Epoch 112/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3889 - accuracy: 0.8400
# Epoch 113/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3802 - accuracy: 0.8200
# Epoch 114/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.
200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3751 - accuracy: 0.7933
# Epoch 176/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3775 - accuracy: 0.8200
# Epoch 177/200
# 5/5 [==============================] - 0s 3ms/step - loss: 0.3752 - accuracy: 0.8133
# Epoch 178/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3835 - accuracy: 0.8267
# Epoch 179/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3769 - accuracy: 0.7933
# Epoch 180/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3763 - accuracy: 0.8200
# Epoch 181/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3719 - accuracy: 0.8267
# Epoch 182/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3804 - accuracy: 0.7600
# Epoch 183/200
# 5/5 [==============================] - 0s 2ms/step - loss: 0.3717 - accuracy: 0.8400
# Epoch 184/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3797 - accuracy: 0.7933
# Epoch 185/200
# 5/5 [==============================] - 0s 272us/step - loss: 0.3713 - accuracy: 0.8067
# Epoch 186/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3738 - accuracy: 0.8400
# Epoch 187/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3781 - accuracy: 0.7933
# Epoch 188/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3753 - accuracy: 0.8200
# Epoch 189/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3710 - accuracy: 0.8333
# Epoch 190/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3740 - accuracy: 0.7933
# Epoch 191/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3704 - accuracy: 0.8133
# Epoch 192/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3774 - accuracy: 0.8400
# Epoch 193/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3698 - accuracy: 0.8200
# Epoch 194/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3835 - accuracy: 0.7733
# Epoch 195/200
# 5/5 [==============================] - 0s 213us/step - loss: 0.3709 - accuracy: 0.8267
# Epoch 196/200
# 5/5 [==============================] - 0s 5ms/step - loss: 0.3739 - accuracy: 0.7933
# Epoch 197/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3740 - accuracy: 0.8000
# Epoch 198/200
# 5/5 [==============================] - 0s 0s/step - loss: 0.3709 - accuracy: 0.8267
# Epoch 199/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3725 - accuracy: 0.8200
# Epoch 200/200
# 5/5 [==============================] - 0s 4ms/step - loss: 0.3755 - accuracy: 0.8267

# %%
keras_loss, keras_acc = model.evaluate(X_norm, y_onehot, verbose=0)

# keras_loss_train, keras_acc_train = model.evaluate(X_train, y_train, verbose=0)

# keras_loss_test, keras_acc_test= model.evaluate(X_test, y_test, verbose=0)

keras_weights = model.get_weights()[0]

# %%
X_rate_data=np.zeros((X_rate.shape[0],X_rate.shape[1],f_sample))

for m,sample in enumerate(X_rate):
    
    for n,feature in enumerate(sample):
        
        X_rate_data[m,n,:]=np.zeros(f_sample)
        
        if feature>0:
        
            X_rate_data[m,n,0:-1:round(f_sample/feature)]=1

# %%
def one_iteration(X_rate_data,keras_weights,f_sample,net,proc,st_point=[0,1,2,3],n_id =[0,1,2],
                  type_id=["output","output","output"],abs_period=[1,10,1]):

    y_pred = []
    
    spike_max_ = np.zeros((X_rate_data.shape[0],len(n_id)))

    for i in range(len(X_rate_data)):

        net = create_custom_network()

        net.add_stimuli(st_point,n_id,X_rate_data[i],keras_weights)

        for (i,j,k) in zip(n_id,type_id,abs_period):

            net.add_neuron(i,j)
            
            net.neuron[i].abs_period=k

    #     net.add_neuron(1,"output")

    #     net.add_neuron(2,"output")

        proc=MRAVENS(-5,5)

        event=process_event(f_sample,net,proc)

        event.apply_spike()
        
        spike_max = np.argmax(np.sum(event.spikes_,axis=0))
        
        spike_max_[i,spike_max]=1

        y_pred.append(spike_max)
        
    return np.array(y_pred), spike_max_

# %%
y_pred, spike_max=one_iteration(X_rate_data,keras_weights,f_sample,net,proc,st_point=[0,1,2,3],n_id =[0,1,2],type_id=["output","output","output"],abs_period=[4,4,3])

# %%
acc = len(y[y_pred==y])/len(y)

print(f"Keras Accuracy: {keras_acc} ::: Neuromorphic Accuracy: {acc}")
# Out:
# Keras Accuracy: 0.8266666531562805 ::: Neuromorphic Accuracy: 0.8133333333333334
