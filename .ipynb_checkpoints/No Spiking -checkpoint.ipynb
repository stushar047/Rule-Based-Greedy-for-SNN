# %%
import numpy as np

import matplotlib.pyplot as plt

from sklearn.datasets import load_iris,load_wine, load_breast_cancer

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split

from mravens_icons import *

import tensorflow as tf

from tensorflow.keras import Sequential

from tensorflow.keras.layers import Dense

import json

# Define the file path
json_file = "config_data.json"

# Read the JSON file
with open(json_file, 'r') as file:
    data = json.load(file)

# Extract values from the data dictionary
seed = data["seed"]
f_sample = data["f_sample"]
epochs = 500
app = "iris"
lr = 0.1
b1 = 0.75
b2 = 0.999
batch_size = 16

np.random.seed(seed)

tf.random.set_seed(seed)

def one_hot(y,n):
    
    y_onehot = np.zeros((len(y),n))

    for i,j in enumerate(y):

        y_onehot[i,j]=1
        
    return y_onehot

def train_test_data(application="iris",f_sample=32,seed = 42, test_size=0.20):

    if application=="iris":

        data=load_iris()

        X,y=data['data'],data['target']  
    
    elif application=="wine":
        
        data = load_wine()

        X,y=data['data'],data['target']
        
    elif application=="breast_cancer":
        
        data=load_breast_cancer()

        X,y=data['data'],data['target']

    y_onehot = one_hot(y,np.max(y)+1)
    
    X_norm=(X-np.min(X,axis=0))/(np.max(X,axis=0)-np.min(X,axis=0))

    X_train,X_test,ytrain,ytest = train_test_split(X_norm,y,test_size=0.20,random_state=seed, stratify=y)
    
    y_train, y_test = one_hot(ytrain,np.max(y)+1), one_hot(ytest,np.max(y)+1)
    
    return X_train,X_test,y_train,y_test, ytrain,ytest

def get_GD_based_synaptic_weights(X_train,y_train,loss='categorical_crossentropy',activation='softmax',lr=0.1,
                                  b1=0.7,b2=0.999,epochs=200, batch_size=64, verbose=1,seed=42,shuffle=False):

    tf.random.set_seed(seed)

    # Define the input shape
    input_shape = (X_train.shape[1],)  # Replace input_size with the size of your input

    # Create a Sequential model
    model = Sequential()

    initializer = tf.keras.initializers.HeNormal()

    # Add the output layer directly
    model.add(Dense(units=y_train.shape[1], input_shape=input_shape, activation=activation,use_bias=False, kernel_initializer=initializer))

    opt = tf.keras.optimizers.Adam(learning_rate=lr,beta_1=b1,beta_2=b2)

    model.compile(loss=loss, optimizer=opt, metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=verbose, validation_data=(X_test,y_test),shuffle=shuffle)

    keras_loss_train, keras_acc_train = model.evaluate(X_train, y_train, verbose=0)

    keras_loss_test, keras_acc_test= model.evaluate(X_test, y_test, verbose=0)

    keras_weights = model.get_weights()[0]
    
    return keras_loss_train, keras_acc_train, keras_loss_test, keras_acc_test, keras_weights

"""
Train_Test_Data
"""

X_train,X_test,y_train,y_test,ytrain,ytest=train_test_data(application=app,f_sample=f_sample,seed=seed, test_size=0.20)

"""
Keras Weights
"""

keras_loss_train, keras_acc_train, keras_loss_test, keras_acc_test, keras_weights = get_GD_based_synaptic_weights(X_train,y_train,activation='softmax',lr=lr,b1=b1,b2=b2,epochs=epochs, batch_size=batch_size, verbose=1,seed=seed,shuffle=False)
# Out:
# Epoch 1/500
# 8/8 [==============================] - 1s 62ms/step - loss: 1.1478 - accuracy: 0.2083 - val_loss: 0.9221 - val_accuracy: 0.4333
# Epoch 2/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.8483 - accuracy: 0.6000 - val_loss: 0.7577 - val_accuracy: 0.6667
# Epoch 3/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.7217 - accuracy: 0.6667 - val_loss: 0.6596 - val_accuracy: 0.6667
# Epoch 4/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.6463 - accuracy: 0.6667 - val_loss: 0.6008 - val_accuracy: 0.6667
# Epoch 5/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5993 - accuracy: 0.6583 - val_loss: 0.5623 - val_accuracy: 0.6667
# Epoch 6/500
# 8/8 [==============================] - 0s 12ms/step - loss: 0.5676 - accuracy: 0.6583 - val_loss: 0.5356 - val_accuracy: 0.6667
# Epoch 7/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.5449 - accuracy: 0.6750 - val_loss: 0.5159 - val_accuracy: 0.6667
# Epoch 8/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.5277 - accuracy: 0.6750 - val_loss: 0.5007 - val_accuracy: 0.6667
# Epoch 9/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5143 - accuracy: 0.6833 - val_loss: 0.4886 - val_accuracy: 0.7000
# Epoch 10/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.5035 - accuracy: 0.6833 - val_loss: 0.4786 - val_accuracy: 0.7000
# Epoch 11/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4945 - accuracy: 0.6833 - val_loss: 0.4703 - val_accuracy: 0.6667
# Epoch 12/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4869 - accuracy: 0.6750 - val_loss: 0.4631 - val_accuracy: 0.7333
# Epoch 13/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4803 - accuracy: 0.6833 - val_loss: 0.4568 - val_accuracy: 0.7667
# Epoch 14/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4746 - accuracy: 0.7000 - val_loss: 0.4513 - val_accuracy: 0.7667
# Epoch 15/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4696 - accuracy: 0.7000 - val_loss: 0.4464 - val_accuracy: 0.7667
# Epoch 16/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4651 - accuracy: 0.7167 - val_loss: 0.4420 - val_accuracy: 0.7667
# Epoch 17/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4611 - accuracy: 0.7250 - val_loss: 0.4379 - val_accuracy: 0.7667
# Epoch 18/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.4575 - accuracy: 0.7417 - val_loss: 0.4343 - val_accuracy: 0.7667
# Epoch 19/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4541 - accuracy: 0.7333 - val_loss: 0.4309 - val_accuracy: 0.7667
# Epoch 20/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4511 - accuracy: 0.7333 - val_loss: 0.4279 - val_accuracy: 0.7667
# Epoch 21/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4483 - accuracy: 0.7500 - val_loss: 0.4250 - val_accuracy: 0.7667
# Epoch 22/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4457 - accuracy: 0.7500 - val_loss: 0.4223 - val_accuracy: 0.7667
# Epoch 23/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4433 - accuracy: 0.7500 - val_loss: 0.4199 - val_accuracy: 0.7667
# Epoch 24/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4410 - accuracy: 0.7500 - val_loss: 0.4175 - val_accuracy: 0.7667
# Epoch 25/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4389 - accuracy: 0.7583 - val_loss: 0.4154 - val_accuracy: 0.7667
# Epoch 26/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4369 - accuracy: 0.7667 - val_loss: 0.4133 - val_accuracy: 0.7667
# Epoch 27/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4350 - accuracy: 0.7667 - val_loss: 0.4114 - val_accuracy: 0.7667
# Epoch 28/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4333 - accuracy: 0.7750 - val_loss: 0.4096 - val_accuracy: 0.8000
# Epoch 29/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4316 - accuracy: 0.7667 - val_loss: 0.4079 - val_accuracy: 0.8000
# Epoch 30/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4300 - accuracy: 0.7667 - val_loss: 0.4063 - val_accuracy: 0.8333
# Epoch 31/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4285 - accuracy: 0.7667 - val_loss: 0.4047 - val_accuracy: 0.8333
# Epoch 32/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4270 - accuracy: 0.7667 - val_loss: 0.4033 - val_accuracy: 0.8333
# Epoch 33/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4256 - accuracy: 0.7667 - val_loss: 0.4019 - val_accuracy: 0.8333
# Epoch 34/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4243 - accuracy: 0.7667 - val_loss: 0.4006 - val_accuracy: 0.8333
# Epoch 35/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4230 - accuracy: 0.7667 - val_loss: 0.3993 - val_accuracy: 0.8333
# Epoch 36/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4218 - accuracy: 0.7667 - val_loss: 0.3982 - val_accuracy: 0.8000
# Epoch 37/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4206 - accuracy: 0.7833 - val_loss: 0.3970 - val_accuracy: 0.8000
# Epoch 38/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4195 - accuracy: 0.7833 - val_loss: 0.3960 - val_accuracy: 0.8000
# Epoch 39/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4184 - accuracy: 0.7917 - val_loss: 0.3949 - val_accuracy: 0.8000
# Epoch 40/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4174 - accuracy: 0.7833 - val_loss: 0.3940 - val_accuracy: 0.8000
# Epoch 41/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4164 - accuracy: 0.7833 - val_loss: 0.3930 - val_accuracy: 0.8000
# Epoch 42/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4154 - accuracy: 0.7833 - val_loss: 0.3921 - val_accuracy: 0.8000
# Epoch 43/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4144 - accuracy: 0.7833 - val_loss: 0.3913 - val_accuracy: 0.8000
# Epoch 44/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.4135 - accuracy: 0.7917 - val_loss: 0.3905 - val_accuracy: 0.8000
# Epoch 45/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4126 - accuracy: 0.8000 - val_loss: 0.3897 - val_accuracy: 0.8000
# Epoch 46/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4118 - accuracy: 0.8000 - val_loss: 0.3889 - val_accuracy: 0.8000
# Epoch 47/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4109 - accuracy: 0.8000 - val_loss: 0.3882 - val_accuracy: 0.8000
# Epoch 48/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4101 - accuracy: 0.8000 - val_loss: 0.3876 - val_accuracy: 0.8000
# Epoch 49/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4093 - accuracy: 0.8000 - val_loss: 0.3869 - val_accuracy: 0.8000
# Epoch 50/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4086 - accuracy: 0.8000 - val_loss: 0.3863 - val_accuracy: 0.8000
# Epoch 51/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4078 - accuracy: 0.8000 - val_loss: 0.3857 - val_accuracy: 0.8000
# Epoch 52/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4071 - accuracy: 0.8000 - val_loss: 0.3851 - val_accuracy: 0.8000
# Epoch 53/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4064 - accuracy: 0.8000 - val_loss: 0.3846 - val_accuracy: 0.8000
# Epoch 54/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4057 - accuracy: 0.8000 - val_loss: 0.3841 - val_accuracy: 0.8000
# Epoch 55/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4051 - accuracy: 0.8000 - val_loss: 0.3836 - val_accuracy: 0.8000
# Epoch 56/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.4044 - accuracy: 0.8000 - val_loss: 0.3831 - val_accuracy: 0.8000
# Epoch 57/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4038 - accuracy: 0.8000 - val_loss: 0.3826 - val_accuracy: 0.8000
# Epoch 58/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4032 - accuracy: 0.8000 - val_loss: 0.3822 - val_accuracy: 0.8000
# Epoch 59/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4026 - accuracy: 0.8000 - val_loss: 0.3818 - val_accuracy: 0.8000
# Epoch 60/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.4020 - accuracy: 0.8000 - val_loss: 0.3814 - val_accuracy: 0.8000
# Epoch 61/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4014 - accuracy: 0.8000 - val_loss: 0.3810 - val_accuracy: 0.8000
# Epoch 62/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.4008 - accuracy: 0.8083 - val_loss: 0.3807 - val_accuracy: 0.8000
# Epoch 63/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.4003 - accuracy: 0.8083 - val_loss: 0.3803 - val_accuracy: 0.8000
# Epoch 64/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3998 - accuracy: 0.8083 - val_loss: 0.3800 - val_accuracy: 0.8000
# Epoch 65/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3992 - accuracy: 0.8083 - val_loss: 0.3797 - val_accuracy: 0.8000
# Epoch 66/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3987 - accuracy: 0.8083 - val_loss: 0.3794 - val_accuracy: 0.8000
# Epoch 67/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3982 - accuracy: 0.8083 - val_loss: 0.3791 - val_accuracy: 0.8000
# Epoch 68/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3977 - accuracy: 0.8083 - val_loss: 0.3788 - val_accuracy: 0.8000
# Epoch 69/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3973 - accuracy: 0.8083 - val_loss: 0.3785 - val_accuracy: 0.8000
# Epoch 70/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3968 - accuracy: 0.8083 - val_loss: 0.3783 - val_accuracy: 0.8000
# Epoch 71/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3963 - accuracy: 0.8083 - val_loss: 0.3780 - val_accuracy: 0.8000
# Epoch 72/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3959 - accuracy: 0.8083 - val_loss: 0.3778 - val_accuracy: 0.8000
# Epoch 73/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3954 - accuracy: 0.8083 - val_loss: 0.3776 - val_accuracy: 0.8000
# Epoch 74/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3950 - accuracy: 0.8083 - val_loss: 0.3774 - val_accuracy: 0.8000
# Epoch 75/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3946 - accuracy: 0.8083 - val_loss: 0.3772 - val_accuracy: 0.8000
# Epoch 76/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3942 - accuracy: 0.8083 - val_loss: 0.3770 - val_accuracy: 0.8000
# Epoch 77/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3938 - accuracy: 0.8083 - val_loss: 0.3768 - val_accuracy: 0.8000
# Epoch 78/500
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3934 - accuracy: 0.8083 - val_loss: 0.3767 - val_accuracy: 0.8000
# Epoch 79/500
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3930 - accuracy: 0.8083 - val_loss: 0.3765 - val_accuracy: 0.8000
# Epoch 80/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3926 - accuracy: 0.8083 - val_loss: 0.3764 - val_accuracy: 0.8000
# Epoch 81/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3922 - accuracy: 0.8083 - val_loss: 0.3762 - val_accuracy: 0.8000
# Epoch 82/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3919 - accuracy: 0.8083 - val_loss: 0.3761 - val_accuracy: 0.8333
# Epoch 83/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3915 - accuracy: 0.8083 - val_loss: 0.3760 - val_accuracy: 0.8333
# Epoch 84/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3912 - accuracy: 0.8083 - val_loss: 0.3759 - val_accuracy: 0.8333
# Epoch 85/500
# 8/8 [==============================] - 0s 12ms/step - loss: 0.3908 - accuracy: 0.8083 - val_loss: 0.3757 - val_accuracy: 0.8333
# Epoch 86/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3905 - accuracy: 0.8083 - val_loss: 0.3756 - val_accuracy: 0.8333
# Epoch 87/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3902 - accuracy: 0.8083 - val_loss: 0.3755 - val_accuracy: 0.8333
# Epoch 88/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3898 - accuracy: 0.8083 - val_loss: 0.3754 - val_accuracy: 0.8333
# Epoch 89/500
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3895 - accuracy: 0.8083 - val_loss: 0.3754 - val_accuracy: 0.8333
# Epoch 90/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3892 - accuracy: 0.8083 - val_loss: 0.3753 - val_accuracy: 0.8333
# Epoch 91/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3889 - accuracy: 0.8083 - val_loss: 0.3752 - val_accuracy: 0.8333
# Epoch 92/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3886 - accuracy: 0.8083 - val_loss: 0.3751 - val_accuracy: 0.8333
# Epoch 93/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3883 - accuracy: 0.8083 - val_loss: 0.3751 - val_accuracy: 0.8333
# Epoch 94/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3880 - accuracy: 0.8083 - val_loss: 0.3750 - val_accuracy: 0.8333
# Epoch 95/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3877 - accuracy: 0.8083 - val_loss: 0.3750 - val_accuracy: 0.8333
# Epoch 96/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3875 - accuracy: 0.8083 - val_loss: 0.3749 - val_accuracy: 0.8333
# Epoch 97/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3872 - accuracy: 0.8083 - val_loss: 0.3749 - val_accuracy: 0.8333
# Epoch 98/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3869 - accuracy: 0.8083 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 99/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3866 - accuracy: 0.8083 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 100/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3864 - accuracy: 0.8083 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 101/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3861 - accuracy: 0.8083 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 102/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3859 - accuracy: 0.8083 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 103/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3856 - accuracy: 0.8083 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 104/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3854 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 105/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3852 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 106/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3849 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 107/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3847 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 108/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3845 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 109/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3842 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 110/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3840 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 111/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3838 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 112/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3836 - accuracy: 0.8167 - val_loss: 0.3746 - val_accuracy: 0.8333
# Epoch 113/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3834 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 114/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3832 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 115/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3830 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 116/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3828 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 117/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3826 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 118/500
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3824 - accuracy: 0.8167 - val_loss: 0.3747 - val_accuracy: 0.8333
# Epoch 119/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3822 - accuracy: 0.8167 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 120/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3820 - accuracy: 0.8167 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 121/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3818 - accuracy: 0.8167 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 122/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3817 - accuracy: 0.8167 - val_loss: 0.3748 - val_accuracy: 0.8333
# Epoch 123/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3815 - accuracy: 0.8167 - val_loss: 0.3749 - val_accuracy: 0.8333
# Epoch 124/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3813 - accuracy: 0.8167 - val_loss: 0.3749 - val_accuracy: 0.8333
# Epoch 125/500
# 8/8 [==============================] - 0s 13ms/step - loss: 0.3811 - accuracy: 0.8167 - val_loss: 0.3749 - val_accuracy: 0.8333
# Epoch 126/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3810 - accuracy: 0.8167 - val_loss: 0.3750 - val_accuracy: 0.8333
# Epoch 127/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3808 - accuracy: 0.8167 - val_loss: 0.3750 - val_accuracy: 0.8333
# Epoch 128/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3806 - accuracy: 0.8167 - val_loss: 0.3750 - val_accuracy: 0.8333
# Epoch 129/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3805 - accuracy: 0.8167 - val_loss: 0.3751 - val_accuracy: 0.8333
# Epoch 130/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3803 - accuracy: 0.8167 - val_loss: 0.3751 - val_accuracy: 0.8333
# Epoch 131/500
# 8/8 [==============================] - 0s 11ms/step - loss: 0.3802 - accuracy: 0.8167 - val_loss: 0.3752 - val_accuracy: 0.8333
# Epoch 132/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3800 - accuracy: 0.8167 - val_loss: 0.3752 - val_accuracy: 0.8333
# Epoch 133/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3799 - accuracy: 0.8167 - val_loss: 0.3753 - val_accuracy: 0.8333
# Epoch 134/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3797 - accuracy: 0.8167 - val_loss: 0.3753 - val_accuracy: 0.8333
# Epoch 135/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3796 - accuracy: 0.8167 - val_loss: 0.3754 - val_accuracy: 0.8333
# Epoch 136/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3794 - accuracy: 0.8167 - val_loss: 0.3754 - val_accuracy: 0.8333
# Epoch 137/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3793 - accuracy: 0.8167 - val_loss: 0.3755 - val_accuracy: 0.8333
# Epoch 138/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3792 - accuracy: 0.8167 - val_loss: 0.3755 - val_accuracy: 0.8333
# Epoch 139/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3790 - accuracy: 0.8167 - val_loss: 0.3756 - val_accuracy: 0.8333
# Epoch 140/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3789 - accuracy: 0.8250 - val_loss: 0.3756 - val_accuracy: 0.8333
# Epoch 141/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3787 - accuracy: 0.8333 - val_loss: 0.3757 - val_accuracy: 0.8333
# Epoch 142/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3786 - accuracy: 0.8333 - val_loss: 0.3757 - val_accuracy: 0.8333
# Epoch 143/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3785 - accuracy: 0.8333 - val_loss: 0.3758 - val_accuracy: 0.8333
# Epoch 144/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3784 - accuracy: 0.8333 - val_loss: 0.3758 - val_accuracy: 0.8333
# Epoch 145/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3782 - accuracy: 0.8333 - val_loss: 0.3759 - val_accuracy: 0.8333
# Epoch 146/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3781 - accuracy: 0.8333 - val_loss: 0.3760 - val_accuracy: 0.8333
# Epoch 147/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3780 - accuracy: 0.8250 - val_loss: 0.3760 - val_accuracy: 0.8333
# Epoch 148/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3779 - accuracy: 0.8250 - val_loss: 0.3761 - val_accuracy: 0.8333
# Epoch 149/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3777 - accuracy: 0.8250 - val_loss: 0.3761 - val_accuracy: 0.8333
# Epoch 150/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3776 - accuracy: 0.8250 - val_loss: 0.3762 - val_accuracy: 0.8333
# Epoch 151/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3775 - accuracy: 0.8250 - val_loss: 0.3763 - val_accuracy: 0.8333
# Epoch 152/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3774 - accuracy: 0.8250 - val_loss: 0.3763 - val_accuracy: 0.8333
# Epoch 153/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3773 - accuracy: 0.8250 - val_loss: 0.3764 - val_accuracy: 0.8333
# Epoch 154/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3772 - accuracy: 0.8250 - val_loss: 0.3764 - val_accuracy: 0.8333
# Epoch 155/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3771 - accuracy: 0.8250 - val_loss: 0.3765 - val_accuracy: 0.8333
# Epoch 156/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3770 - accuracy: 0.8250 - val_loss: 0.3766 - val_accuracy: 0.8333
# Epoch 157/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3769 - accuracy: 0.8250 - val_loss: 0.3766 - val_accuracy: 0.8333
# Epoch 158/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3767 - accuracy: 0.8333 - val_loss: 0.3767 - val_accuracy: 0.8333
# Epoch 159/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3766 - accuracy: 0.8333 - val_loss: 0.3768 - val_accuracy: 0.8333
# Epoch 160/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3765 - accuracy: 0.8333 - val_loss: 0.3768 - val_accuracy: 0.8333
# Epoch 161/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3764 - accuracy: 0.8333 - val_loss: 0.3769 - val_accuracy: 0.8333
# Epoch 162/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3763 - accuracy: 0.8333 - val_loss: 0.3770 - val_accuracy: 0.8333
# Epoch 163/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3762 - accuracy: 0.8333 - val_loss: 0.3770 - val_accuracy: 0.8333
# Epoch 164/500
# 8/8 [==============================] - 0s 10ms/step - loss: 0.3762 - accuracy: 0.8333 - val_loss: 0.3771 - val_accuracy: 0.8333
# Epoch 165/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3761 - accuracy: 0.8333 - val_loss: 0.3772 - val_accuracy: 0.8333
# Epoch 166/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3760 - accuracy: 0.8333 - val_loss: 0.3772 - val_accuracy: 0.8333
# Epoch 167/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3759 - accuracy: 0.8333 - val_loss: 0.3773 - val_accuracy: 0.8333
# Epoch 168/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3758 - accuracy: 0.8333 - val_loss: 0.3774 - val_accuracy: 0.8333
# Epoch 169/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3757 - accuracy: 0.8333 - val_loss: 0.3774 - val_accuracy: 0.8333
# Epoch 170/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3756 - accuracy: 0.8333 - val_loss: 0.3775 - val_accuracy: 0.8333
# Epoch 171/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3755 - accuracy: 0.8333 - val_loss: 0.3776 - val_accuracy: 0.8333
# Epoch 172/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3754 - accuracy: 0.8333 - val_loss: 0.3776 - val_accuracy: 0.8333
# Epoch 173/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3753 - accuracy: 0.8333 - val_loss: 0.3777 - val_accuracy: 0.8333
# Epoch 174/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3753 - accuracy: 0.8333 - val_loss: 0.3778 - val_accuracy: 0.8333
# Epoch 175/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3752 - accuracy: 0.8333 - val_loss: 0.3779 - val_accuracy: 0.8333
# Epoch 176/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3751 - accuracy: 0.8333 - val_loss: 0.3779 - val_accuracy: 0.8333
# Epoch 177/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3750 - accuracy: 0.8333 - val_loss: 0.3780 - val_accuracy: 0.8333
# Epoch 178/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3749 - accuracy: 0.8333 - val_loss: 0.3781 - val_accuracy: 0.8333
# Epoch 179/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3749 - accuracy: 0.8333 - val_loss: 0.3781 - val_accuracy: 0.8333
# Epoch 180/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3748 - accuracy: 0.8333 - val_loss: 0.3782 - val_accuracy: 0.8333
# Epoch 181/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3747 - accuracy: 0.8333 - val_loss: 0.3783 - val_accuracy: 0.8333
# Epoch 182/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3746 - accuracy: 0.8333 - val_loss: 0.3783 - val_accuracy: 0.8333
# Epoch 183/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3745 - accuracy: 0.8333 - val_loss: 0.3784 - val_accuracy: 0.8667
# Epoch 184/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3745 - accuracy: 0.8333 - val_loss: 0.3785 - val_accuracy: 0.8667
# Epoch 185/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3744 - accuracy: 0.8333 - val_loss: 0.3786 - val_accuracy: 0.8667
# Epoch 186/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3743 - accuracy: 0.8333 - val_loss: 0.3786 - val_accuracy: 0.8667
# Epoch 187/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3743 - accuracy: 0.8333 - val_loss: 0.3787 - val_accuracy: 0.8667
# Epoch 188/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3742 - accuracy: 0.8333 - val_loss: 0.3788 - val_accuracy: 0.8667
# Epoch 189/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3741 - accuracy: 0.8333 - val_loss: 0.3788 - val_accuracy: 0.8667
# Epoch 190/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3740 - accuracy: 0.8333 - val_loss: 0.3789 - val_accuracy: 0.8667
# Epoch 191/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3740 - accuracy: 0.8333 - val_loss: 0.3790 - val_accuracy: 0.8667
# Epoch 192/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3739 - accuracy: 0.8333 - val_loss: 0.3790 - val_accuracy: 0.8667
# Epoch 193/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3738 - accuracy: 0.8333 - val_loss: 0.3791 - val_accuracy: 0.8667
# Epoch 194/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3738 - accuracy: 0.8333 - val_loss: 0.3792 - val_accuracy: 0.8667
# Epoch 195/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3737 - accuracy: 0.8333 - val_loss: 0.3793 - val_accuracy: 0.8667
# Epoch 196/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3736 - accuracy: 0.8333 - val_loss: 0.3793 - val_accuracy: 0.8667
# Epoch 197/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3736 - accuracy: 0.8333 - val_loss: 0.3794 - val_accuracy: 0.8667
# Epoch 198/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3735 - accuracy: 0.8333 - val_loss: 0.3795 - val_accuracy: 0.8667
# Epoch 199/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3735 - accuracy: 0.8333 - val_loss: 0.3795 - val_accuracy: 0.8667
# Epoch 200/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3734 - accuracy: 0.8333 - val_loss: 0.3796 - val_accuracy: 0.8667
# Epoch 201/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3733 - accuracy: 0.8333 - val_loss: 0.3797 - val_accuracy: 0.8667
# Epoch 202/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3733 - accuracy: 0.8250 - val_loss: 0.3797 - val_accuracy: 0.8667
# Epoch 203/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3732 - accuracy: 0.8250 - val_loss: 0.3798 - val_accuracy: 0.8667
# Epoch 204/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3732 - accuracy: 0.8250 - val_loss: 0.3799 - val_accuracy: 0.8667
# Epoch 205/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3731 - accuracy: 0.8250 - val_loss: 0.3800 - val_accuracy: 0.8667
# Epoch 206/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3730 - accuracy: 0.8250 - val_loss: 0.3800 - val_accuracy: 0.8667
# Epoch 207/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3730 - accuracy: 0.8250 - val_loss: 0.3801 - val_accuracy: 0.8667
# Epoch 208/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3729 - accuracy: 0.8250 - val_loss: 0.3802 - val_accuracy: 0.8667
# Epoch 209/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3729 - accuracy: 0.8250 - val_loss: 0.3802 - val_accuracy: 0.8667
# Epoch 210/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3728 - accuracy: 0.8250 - val_loss: 0.3803 - val_accuracy: 0.8667
# Epoch 211/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3728 - accuracy: 0.8250 - val_loss: 0.3804 - val_accuracy: 0.8667
# Epoch 212/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3727 - accuracy: 0.8250 - val_loss: 0.3804 - val_accuracy: 0.8667
# Epoch 213/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3727 - accuracy: 0.8250 - val_loss: 0.3805 - val_accuracy: 0.8667
# Epoch 214/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3726 - accuracy: 0.8250 - val_loss: 0.3806 - val_accuracy: 0.8667
# Epoch 215/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3726 - accuracy: 0.8250 - val_loss: 0.3806 - val_accuracy: 0.8667
# Epoch 216/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3725 - accuracy: 0.8250 - val_loss: 0.3807 - val_accuracy: 0.8667
# Epoch 217/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3725 - accuracy: 0.8250 - val_loss: 0.3808 - val_accuracy: 0.8667
# Epoch 218/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3724 - accuracy: 0.8250 - val_loss: 0.3808 - val_accuracy: 0.8667
# Epoch 219/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3724 - accuracy: 0.8250 - val_loss: 0.3809 - val_accuracy: 0.8667
# Epoch 220/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3723 - accuracy: 0.8250 - val_loss: 0.3810 - val_accuracy: 0.8667
# Epoch 221/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3723 - accuracy: 0.8250 - val_loss: 0.3811 - val_accuracy: 0.8667
# Epoch 222/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3722 - accuracy: 0.8250 - val_loss: 0.3811 - val_accuracy: 0.8667
# Epoch 223/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3722 - accuracy: 0.8250 - val_loss: 0.3812 - val_accuracy: 0.8667
# Epoch 224/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3721 - accuracy: 0.8250 - val_loss: 0.3813 - val_accuracy: 0.8667
# Epoch 225/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3721 - accuracy: 0.8250 - val_loss: 0.3813 - val_accuracy: 0.8667
# Epoch 226/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3720 - accuracy: 0.8250 - val_loss: 0.3814 - val_accuracy: 0.8667
# Epoch 227/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3720 - accuracy: 0.8250 - val_loss: 0.3815 - val_accuracy: 0.8667
# Epoch 228/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3719 - accuracy: 0.8250 - val_loss: 0.3815 - val_accuracy: 0.8667
# Epoch 229/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3719 - accuracy: 0.8250 - val_loss: 0.3816 - val_accuracy: 0.8667
# Epoch 230/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3719 - accuracy: 0.8250 - val_loss: 0.3816 - val_accuracy: 0.8667
# Epoch 231/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3718 - accuracy: 0.8250 - val_loss: 0.3817 - val_accuracy: 0.8667
# Epoch 232/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3718 - accuracy: 0.8250 - val_loss: 0.3818 - val_accuracy: 0.8667
# Epoch 233/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3717 - accuracy: 0.8250 - val_loss: 0.3818 - val_accuracy: 0.8667
# Epoch 234/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3717 - accuracy: 0.8250 - val_loss: 0.3819 - val_accuracy: 0.8667
# Epoch 235/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.8250 - val_loss: 0.3820 - val_accuracy: 0.8667
# Epoch 236/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.8250 - val_loss: 0.3820 - val_accuracy: 0.8667
# Epoch 237/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.8250 - val_loss: 0.3821 - val_accuracy: 0.8667
# Epoch 238/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3715 - accuracy: 0.8250 - val_loss: 0.3822 - val_accuracy: 0.8667
# Epoch 239/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3715 - accuracy: 0.8250 - val_loss: 0.3822 - val_accuracy: 0.8667
# Epoch 240/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3714 - accuracy: 0.8250 - val_loss: 0.3823 - val_accuracy: 0.8667
# Epoch 241/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3714 - accuracy: 0.8250 - val_loss: 0.3824 - val_accuracy: 0.8667
# Epoch 242/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3714 - accuracy: 0.8250 - val_loss: 0.3824 - val_accuracy: 0.8667
# Epoch 243/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3713 - accuracy: 0.8250 - val_loss: 0.3825 - val_accuracy: 0.8667
# Epoch 244/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3713 - accuracy: 0.8250 - val_loss: 0.3825 - val_accuracy: 0.8667
# Epoch 245/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3713 - accuracy: 0.8250 - val_loss: 0.3826 - val_accuracy: 0.8667
# Epoch 246/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3712 - accuracy: 0.8250 - val_loss: 0.3827 - val_accuracy: 0.8667
# Epoch 247/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3712 - accuracy: 0.8250 - val_loss: 0.3827 - val_accuracy: 0.8667
# Epoch 248/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3711 - accuracy: 0.8250 - val_loss: 0.3828 - val_accuracy: 0.8667
# Epoch 249/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3711 - accuracy: 0.8250 - val_loss: 0.3829 - val_accuracy: 0.8667
# Epoch 250/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3711 - accuracy: 0.8250 - val_loss: 0.3829 - val_accuracy: 0.8667
# Epoch 251/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3710 - accuracy: 0.8250 - val_loss: 0.3830 - val_accuracy: 0.8667
# Epoch 252/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3710 - accuracy: 0.8250 - val_loss: 0.3830 - val_accuracy: 0.8667
# Epoch 253/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3710 - accuracy: 0.8250 - val_loss: 0.3831 - val_accuracy: 0.8667
# Epoch 254/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3709 - accuracy: 0.8250 - val_loss: 0.3832 - val_accuracy: 0.8667
# Epoch 255/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3709 - accuracy: 0.8250 - val_loss: 0.3832 - val_accuracy: 0.8667
# Epoch 256/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3709 - accuracy: 0.8250 - val_loss: 0.3833 - val_accuracy: 0.8667
# Epoch 257/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3708 - accuracy: 0.8250 - val_loss: 0.3833 - val_accuracy: 0.8667
# Epoch 258/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3708 - accuracy: 0.8250 - val_loss: 0.3834 - val_accuracy: 0.8667
# Epoch 259/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3708 - accuracy: 0.8250 - val_loss: 0.3835 - val_accuracy: 0.8667
# Epoch 260/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3707 - accuracy: 0.8250 - val_loss: 0.3835 - val_accuracy: 0.8667
# Epoch 261/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3707 - accuracy: 0.8250 - val_loss: 0.3836 - val_accuracy: 0.8667
# Epoch 262/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3707 - accuracy: 0.8250 - val_loss: 0.3836 - val_accuracy: 0.8667
# Epoch 263/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3706 - accuracy: 0.8250 - val_loss: 0.3837 - val_accuracy: 0.8667
# Epoch 264/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3706 - accuracy: 0.8250 - val_loss: 0.3838 - val_accuracy: 0.8667
# Epoch 265/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3706 - accuracy: 0.8250 - val_loss: 0.3838 - val_accuracy: 0.8667
# Epoch 266/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3705 - accuracy: 0.8250 - val_loss: 0.3839 - val_accuracy: 0.8667
# Epoch 267/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3705 - accuracy: 0.8250 - val_loss: 0.3839 - val_accuracy: 0.8667
# Epoch 268/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3705 - accuracy: 0.8167 - val_loss: 0.3840 - val_accuracy: 0.8667
# Epoch 269/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3704 - accuracy: 0.8167 - val_loss: 0.3840 - val_accuracy: 0.8667
# Epoch 270/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3704 - accuracy: 0.8167 - val_loss: 0.3841 - val_accuracy: 0.8667
# Epoch 271/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3704 - accuracy: 0.8167 - val_loss: 0.3842 - val_accuracy: 0.8667
# Epoch 272/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3704 - accuracy: 0.8167 - val_loss: 0.3842 - val_accuracy: 0.8667
# Epoch 273/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.8167 - val_loss: 0.3843 - val_accuracy: 0.8667
# Epoch 274/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.8167 - val_loss: 0.3843 - val_accuracy: 0.8667
# Epoch 275/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3703 - accuracy: 0.8167 - val_loss: 0.3844 - val_accuracy: 0.8667
# Epoch 276/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3702 - accuracy: 0.8167 - val_loss: 0.3844 - val_accuracy: 0.8667
# Epoch 277/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3702 - accuracy: 0.8167 - val_loss: 0.3845 - val_accuracy: 0.8667
# Epoch 278/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3702 - accuracy: 0.8167 - val_loss: 0.3846 - val_accuracy: 0.8667
# Epoch 279/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3702 - accuracy: 0.8167 - val_loss: 0.3846 - val_accuracy: 0.8667
# Epoch 280/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3701 - accuracy: 0.8167 - val_loss: 0.3847 - val_accuracy: 0.8667
# Epoch 281/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3701 - accuracy: 0.8167 - val_loss: 0.3847 - val_accuracy: 0.8667
# Epoch 282/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3701 - accuracy: 0.8167 - val_loss: 0.3848 - val_accuracy: 0.8667
# Epoch 283/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3701 - accuracy: 0.8167 - val_loss: 0.3848 - val_accuracy: 0.8667
# Epoch 284/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3700 - accuracy: 0.8167 - val_loss: 0.3849 - val_accuracy: 0.8667
# Epoch 285/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3700 - accuracy: 0.8167 - val_loss: 0.3849 - val_accuracy: 0.8667
# Epoch 286/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3700 - accuracy: 0.8167 - val_loss: 0.3850 - val_accuracy: 0.8667
# Epoch 287/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3700 - accuracy: 0.8167 - val_loss: 0.3850 - val_accuracy: 0.8667
# Epoch 288/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3699 - accuracy: 0.8167 - val_loss: 0.3851 - val_accuracy: 0.8667
# Epoch 289/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3699 - accuracy: 0.8167 - val_loss: 0.3851 - val_accuracy: 0.8667
# Epoch 290/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3699 - accuracy: 0.8167 - val_loss: 0.3852 - val_accuracy: 0.8667
# Epoch 291/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3699 - accuracy: 0.8167 - val_loss: 0.3853 - val_accuracy: 0.8667
# Epoch 292/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8167 - val_loss: 0.3853 - val_accuracy: 0.8667
# Epoch 293/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8167 - val_loss: 0.3854 - val_accuracy: 0.8667
# Epoch 294/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3698 - accuracy: 0.8167 - val_loss: 0.3854 - val_accuracy: 0.8667
# Epoch 295/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3698 - accuracy: 0.8167 - val_loss: 0.3855 - val_accuracy: 0.8667
# Epoch 296/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3697 - accuracy: 0.8167 - val_loss: 0.3855 - val_accuracy: 0.8667
# Epoch 297/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.8167 - val_loss: 0.3856 - val_accuracy: 0.8667
# Epoch 298/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3697 - accuracy: 0.8167 - val_loss: 0.3856 - val_accuracy: 0.8667
# Epoch 299/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3697 - accuracy: 0.8167 - val_loss: 0.3857 - val_accuracy: 0.8667
# Epoch 300/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8167 - val_loss: 0.3857 - val_accuracy: 0.8667
# Epoch 301/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3696 - accuracy: 0.8167 - val_loss: 0.3858 - val_accuracy: 0.8667
# Epoch 302/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8167 - val_loss: 0.3858 - val_accuracy: 0.8667
# Epoch 303/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3696 - accuracy: 0.8167 - val_loss: 0.3859 - val_accuracy: 0.8667
# Epoch 304/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3695 - accuracy: 0.8167 - val_loss: 0.3859 - val_accuracy: 0.8667
# Epoch 305/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3695 - accuracy: 0.8167 - val_loss: 0.3860 - val_accuracy: 0.8667
# Epoch 306/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3695 - accuracy: 0.8167 - val_loss: 0.3860 - val_accuracy: 0.8667
# Epoch 307/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3695 - accuracy: 0.8167 - val_loss: 0.3861 - val_accuracy: 0.8667
# Epoch 308/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3695 - accuracy: 0.8167 - val_loss: 0.3861 - val_accuracy: 0.8667
# Epoch 309/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3694 - accuracy: 0.8167 - val_loss: 0.3862 - val_accuracy: 0.8667
# Epoch 310/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3694 - accuracy: 0.8167 - val_loss: 0.3862 - val_accuracy: 0.8667
# Epoch 311/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3694 - accuracy: 0.8167 - val_loss: 0.3863 - val_accuracy: 0.8667
# Epoch 312/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3694 - accuracy: 0.8167 - val_loss: 0.3863 - val_accuracy: 0.8667
# Epoch 313/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3693 - accuracy: 0.8167 - val_loss: 0.3863 - val_accuracy: 0.8667
# Epoch 314/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3693 - accuracy: 0.8167 - val_loss: 0.3864 - val_accuracy: 0.8667
# Epoch 315/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3693 - accuracy: 0.8167 - val_loss: 0.3864 - val_accuracy: 0.8667
# Epoch 316/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3693 - accuracy: 0.8167 - val_loss: 0.3865 - val_accuracy: 0.8667
# Epoch 317/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3693 - accuracy: 0.8167 - val_loss: 0.3865 - val_accuracy: 0.8667
# Epoch 318/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8167 - val_loss: 0.3866 - val_accuracy: 0.8667
# Epoch 319/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8167 - val_loss: 0.3866 - val_accuracy: 0.8667
# Epoch 320/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8167 - val_loss: 0.3867 - val_accuracy: 0.8667
# Epoch 321/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3692 - accuracy: 0.8167 - val_loss: 0.3867 - val_accuracy: 0.8667
# Epoch 322/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3692 - accuracy: 0.8167 - val_loss: 0.3868 - val_accuracy: 0.8667
# Epoch 323/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8167 - val_loss: 0.3868 - val_accuracy: 0.8667
# Epoch 324/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8167 - val_loss: 0.3869 - val_accuracy: 0.8667
# Epoch 325/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8167 - val_loss: 0.3869 - val_accuracy: 0.8667
# Epoch 326/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8167 - val_loss: 0.3869 - val_accuracy: 0.8667
# Epoch 327/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3691 - accuracy: 0.8167 - val_loss: 0.3870 - val_accuracy: 0.8667
# Epoch 328/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3690 - accuracy: 0.8167 - val_loss: 0.3870 - val_accuracy: 0.8667
# Epoch 329/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3690 - accuracy: 0.8167 - val_loss: 0.3871 - val_accuracy: 0.8667
# Epoch 330/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3690 - accuracy: 0.8167 - val_loss: 0.3871 - val_accuracy: 0.8667
# Epoch 331/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3690 - accuracy: 0.8167 - val_loss: 0.3872 - val_accuracy: 0.8667
# Epoch 332/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3690 - accuracy: 0.8167 - val_loss: 0.3872 - val_accuracy: 0.8667
# Epoch 333/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3690 - accuracy: 0.8167 - val_loss: 0.3873 - val_accuracy: 0.8667
# Epoch 334/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3689 - accuracy: 0.8167 - val_loss: 0.3873 - val_accuracy: 0.8667
# Epoch 335/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3689 - accuracy: 0.8167 - val_loss: 0.3873 - val_accuracy: 0.8667
# Epoch 336/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3689 - accuracy: 0.8167 - val_loss: 0.3874 - val_accuracy: 0.8667
# Epoch 337/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3689 - accuracy: 0.8167 - val_loss: 0.3874 - val_accuracy: 0.8667
# Epoch 338/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3689 - accuracy: 0.8167 - val_loss: 0.3875 - val_accuracy: 0.8667
# Epoch 339/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3688 - accuracy: 0.8167 - val_loss: 0.3875 - val_accuracy: 0.8667
# Epoch 340/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3688 - accuracy: 0.8167 - val_loss: 0.3876 - val_accuracy: 0.8667
# Epoch 341/500
# ...
# Epoch 388/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3681 - accuracy: 0.8167 - val_loss: 0.3894 - val_accuracy: 0.8667
# Epoch 389/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3681 - accuracy: 0.8167 - val_loss: 0.3894 - val_accuracy: 0.8667
# Epoch 390/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3681 - accuracy: 0.8167 - val_loss: 0.3894 - val_accuracy: 0.8667
# Epoch 391/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3681 - accuracy: 0.8167 - val_loss: 0.3895 - val_accuracy: 0.8667
# Epoch 392/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3895 - val_accuracy: 0.8667
# Epoch 393/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3895 - val_accuracy: 0.8667
# Epoch 394/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3896 - val_accuracy: 0.8667
# Epoch 395/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3896 - val_accuracy: 0.8667
# Epoch 396/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3896 - val_accuracy: 0.8667
# Epoch 397/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3897 - val_accuracy: 0.8667
# Epoch 398/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3680 - accuracy: 0.8167 - val_loss: 0.3897 - val_accuracy: 0.8667
# Epoch 399/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3897 - val_accuracy: 0.8667
# Epoch 400/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3897 - val_accuracy: 0.8667
# Epoch 401/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3898 - val_accuracy: 0.8667
# Epoch 402/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3898 - val_accuracy: 0.8667
# Epoch 403/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3898 - val_accuracy: 0.8667
# Epoch 404/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3899 - val_accuracy: 0.8667
# Epoch 405/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3899 - val_accuracy: 0.8667
# Epoch 406/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3679 - accuracy: 0.8167 - val_loss: 0.3899 - val_accuracy: 0.8667
# Epoch 407/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3900 - val_accuracy: 0.8667
# Epoch 408/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3900 - val_accuracy: 0.8667
# Epoch 409/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3900 - val_accuracy: 0.8667
# Epoch 410/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3901 - val_accuracy: 0.8667
# Epoch 411/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3901 - val_accuracy: 0.8667
# Epoch 412/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3901 - val_accuracy: 0.8667
# Epoch 413/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3901 - val_accuracy: 0.8667
# Epoch 414/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3902 - val_accuracy: 0.8667
# Epoch 415/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3678 - accuracy: 0.8167 - val_loss: 0.3902 - val_accuracy: 0.8667
# Epoch 416/500
# 8/8 [==============================] - 0s 8ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3902 - val_accuracy: 0.8667
# Epoch 417/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3903 - val_accuracy: 0.8667
# Epoch 418/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3903 - val_accuracy: 0.8667
# Epoch 419/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3903 - val_accuracy: 0.8667
# Epoch 420/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3904 - val_accuracy: 0.8667
# Epoch 421/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3904 - val_accuracy: 0.8667
# Epoch 422/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3904 - val_accuracy: 0.8667
# Epoch 423/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3677 - accuracy: 0.8167 - val_loss: 0.3904 - val_accuracy: 0.8667
# Epoch 424/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3905 - val_accuracy: 0.8667
# Epoch 425/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3905 - val_accuracy: 0.8667
# Epoch 426/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3905 - val_accuracy: 0.8667
# Epoch 427/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3905 - val_accuracy: 0.8667
# Epoch 428/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3906 - val_accuracy: 0.8667
# Epoch 429/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3906 - val_accuracy: 0.8667
# Epoch 430/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3906 - val_accuracy: 0.8667
# Epoch 431/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3907 - val_accuracy: 0.8667
# Epoch 432/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3676 - accuracy: 0.8167 - val_loss: 0.3907 - val_accuracy: 0.8667
# Epoch 433/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3907 - val_accuracy: 0.8667
# Epoch 434/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3907 - val_accuracy: 0.8667
# Epoch 435/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3908 - val_accuracy: 0.8667
# Epoch 436/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3908 - val_accuracy: 0.8667
# Epoch 437/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3908 - val_accuracy: 0.8667
# Epoch 438/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3908 - val_accuracy: 0.8667
# Epoch 439/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3909 - val_accuracy: 0.8667
# Epoch 440/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3909 - val_accuracy: 0.8667
# Epoch 441/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3675 - accuracy: 0.8167 - val_loss: 0.3909 - val_accuracy: 0.8667
# Epoch 442/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3909 - val_accuracy: 0.8667
# Epoch 443/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3910 - val_accuracy: 0.8667
# Epoch 444/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3910 - val_accuracy: 0.8667
# Epoch 445/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3910 - val_accuracy: 0.8667
# Epoch 446/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3911 - val_accuracy: 0.8667
# Epoch 447/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3911 - val_accuracy: 0.8667
# Epoch 448/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3911 - val_accuracy: 0.8667
# Epoch 449/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3911 - val_accuracy: 0.8667
# Epoch 450/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3912 - val_accuracy: 0.8667
# Epoch 451/500
# 8/8 [==============================] - 0s 9ms/step - loss: 0.3674 - accuracy: 0.8167 - val_loss: 0.3912 - val_accuracy: 0.8667
# Epoch 452/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3912 - val_accuracy: 0.8667
# Epoch 453/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3912 - val_accuracy: 0.8667
# Epoch 454/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3913 - val_accuracy: 0.8667
# Epoch 455/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3913 - val_accuracy: 0.8667
# Epoch 456/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3913 - val_accuracy: 0.8667
# Epoch 457/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3913 - val_accuracy: 0.8667
# Epoch 458/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3913 - val_accuracy: 0.8667
# Epoch 459/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3914 - val_accuracy: 0.8667
# Epoch 460/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3673 - accuracy: 0.8167 - val_loss: 0.3914 - val_accuracy: 0.8667
# Epoch 461/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8167 - val_loss: 0.3914 - val_accuracy: 0.8667
# Epoch 462/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3914 - val_accuracy: 0.8667
# Epoch 463/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3915 - val_accuracy: 0.8667
# Epoch 464/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3915 - val_accuracy: 0.8667
# Epoch 465/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3915 - val_accuracy: 0.8667
# Epoch 466/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3915 - val_accuracy: 0.8667
# Epoch 467/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3916 - val_accuracy: 0.8667
# Epoch 468/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3916 - val_accuracy: 0.8667
# Epoch 469/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3916 - val_accuracy: 0.8667
# Epoch 470/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3672 - accuracy: 0.8250 - val_loss: 0.3916 - val_accuracy: 0.8667
# Epoch 471/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3916 - val_accuracy: 0.8667
# Epoch 472/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3917 - val_accuracy: 0.8667
# Epoch 473/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3917 - val_accuracy: 0.8667
# Epoch 474/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3917 - val_accuracy: 0.8667
# Epoch 475/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3917 - val_accuracy: 0.8667
# Epoch 476/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3918 - val_accuracy: 0.8667
# Epoch 477/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3918 - val_accuracy: 0.8667
# Epoch 478/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3918 - val_accuracy: 0.8667
# Epoch 479/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3918 - val_accuracy: 0.8667
# Epoch 480/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3918 - val_accuracy: 0.8667
# Epoch 481/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3671 - accuracy: 0.8250 - val_loss: 0.3919 - val_accuracy: 0.8667
# Epoch 482/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3919 - val_accuracy: 0.8667
# Epoch 483/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3919 - val_accuracy: 0.8667
# Epoch 484/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3919 - val_accuracy: 0.8667
# Epoch 485/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3919 - val_accuracy: 0.8667
# Epoch 486/500
# 8/8 [==============================] - 0s 4ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3920 - val_accuracy: 0.8667
# Epoch 487/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3920 - val_accuracy: 0.8667
# Epoch 488/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3920 - val_accuracy: 0.8667
# Epoch 489/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3920 - val_accuracy: 0.8667
# Epoch 490/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3921 - val_accuracy: 0.8667
# Epoch 491/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3670 - accuracy: 0.8250 - val_loss: 0.3921 - val_accuracy: 0.8667
# Epoch 492/500
# 8/8 [==============================] - 0s 7ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3921 - val_accuracy: 0.8667
# Epoch 493/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3921 - val_accuracy: 0.8667
# Epoch 494/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3921 - val_accuracy: 0.8667
# Epoch 495/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3922 - val_accuracy: 0.8667
# Epoch 496/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3922 - val_accuracy: 0.8667
# Epoch 497/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3922 - val_accuracy: 0.8667
# Epoch 498/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3922 - val_accuracy: 0.8667
# Epoch 499/500
# 8/8 [==============================] - 0s 5ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3922 - val_accuracy: 0.8667
# Epoch 500/500
# 8/8 [==============================] - 0s 6ms/step - loss: 0.3669 - accuracy: 0.8250 - val_loss: 0.3923 - val_accuracy: 0.8667

# %%
# Sample data
data = {
"keras_loss_train":keras_loss_train, 
"keras_acc_train":keras_acc_train, 
"keras_loss_test":keras_loss_test, 
"keras_acc_test":keras_acc_test, 
"keras_weights":keras_weights.tolist()
}

# File path
file_path = f"{app}_model.json"

# Serialize data to JSON format
json_data = json.dumps(data, indent=4)

# Write JSON data to a file
with open(file_path, "w") as json_file:
    json_file.write(json_data)

print("JSON data has been saved to", file_path)
# Out:
# JSON data has been saved to iris_model.json

# %%
import json

# Read the JSON file
with open(file_path, 'r') as file:
    model_data = json.load(file)

# %%
model_data["keras_weights"]
# Out:
# [[-5.341535568237305, 4.91323184967041],
#  [0.48360520601272583, -0.3608754277229309],
#  [-4.419106960296631, 4.165652751922607],
#  [0.6348662972450256, -0.36088311672210693],
#  [-4.003285884857178, 4.0276031494140625],
#  [0.7950897216796875, -0.47640812397003174],
#  [5.790768146514893, -6.192703723907471],
#  [9.099130630493164, -8.544677734375],
#  [-2.790431499481201, 2.2741169929504395],
#  [-6.705709934234619, 6.610671043395996],
#  [7.020198822021484, -6.624070167541504],
#  [-2.4936609268188477, 2.6727185249328613],
#  [3.665112257003784, -3.2666144371032715],
#  [11.590376853942871, -11.374115943908691],
#  [1.9379774332046509, -1.527440071105957],
#  [-1.50858473777771, 1.1853886842727661],
#  [-4.573840141296387, 4.7860283851623535],
#  [-1.9529228210449219, 2.565364122390747],
#  [-1.6256868839263916, 1.5531665086746216],
#  [-1.3095415830612183, 1.5939445495605469],
#  [-0.6730878949165344, 0.8163017630577087],
#  [2.2871599197387695, -2.373033285140991],
#  [-1.4338407516479492, 0.9869710803031921],
#  [5.366564750671387, -5.068971157073975],
#  [-0.7210834622383118, 0.3583480417728424],
#  [1.110243320465088, -1.3220717906951904],
#  [1.4115163087844849, -0.9262533187866211],
#  [1.5077970027923584, -2.47886061668396],
#  [3.4136343002319336, -3.3584914207458496],
#  [1.2965970039367676, -1.689592719078064]]

# %%
A=np.array([0.96,0.96,0.96,0.96,1,1,1,1,0.87,0.87,0.87,0.87])

B = np.array([0.82,0.87,0.93,0.95,0.78,0.89,0.94,0.97,0.83,0.93,0.97,0.97])

# %%
B-A
# Out:
# array([-0.14, -0.09, -0.03, -0.01, -0.22, -0.11, -0.06, -0.03, -0.04,
#         0.06,  0.1 ,  0.1 ])

# %%
import pandas as pd

# %%
df = pd.read_csv("result_data1.csv")

meth = "D"

app = "wine"

Store_train = []

Store_test = []

Store_abs=[]

df_meth = df[df["method"]==meth]

df_meth_app = df_meth[df_meth["app"]==app]

f = 8
        
nn = df_meth_app[df_meth_app["f_sample"]==f]

nn["tt"] = nn["acctrain"] + nn["acctest"]
# Out:
# <ipython-input-598-bf6fb83cc4d4>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   nn["tt"] = nn["acctrain"] + nn["acctest"]

# %%
nn[nn["tt"] == np.max(nn["tt"].values)]
# Out:
#     f_sample  abs_period_  epochs  abs_epoch method   app  keras_acc_train  \
# 48         8            4     200         50      D  wine         0.992958
#
#     keras_acc_test  acctrain  acctest   absperiod     tt
# 48             1.0     0.796     0.81  [4. 4. 2.]  1.606

# %%
1, 8, 8
# Out:
# (1, 8, 8)

# %%
np.array(Store_train) - np.array([0.96,0.96,0.96,0.96,0.99,0.99,0.99,0.99,0.83,0.83,0.83,0.83])
# Out:
# array([-0.07, -0.07, -0.07, -0.04, -0.19, -0.1 , -0.07, -0.14, -0.16,
#         0.05,  0.05,  0.04])

# %%
np.array(Store_test) - np.array([0.96,0.96,0.96,0.96,1,1,1,1,0.87,0.87,0.87,0.87])
# Out:
# array([-0.13, -0.09, -0.03, -0.06, -0.17, -0.08, -0.08, -0.11, -0.2 ,
#         0.1 ,  0.1 ,  0.06])

# %%
np.array(Store_train)
# Out:
# array([0.89, 0.89, 0.89, 0.92, 0.8 , 0.89, 0.92, 0.85, 0.67, 0.88, 0.88,
#        0.87])

# %%
np.array(Store_test)
# Out:
# array([0.83, 0.87, 0.93, 0.9 , 0.83, 0.92, 0.92, 0.89, 0.67, 0.97, 0.97,
#        0.93])

# %%
import numpy as np

import matplotlib.pyplot as plt

from sklearn.datasets import load_iris,load_wine, load_breast_cancer

from sklearn.preprocessing import StandardScaler, MinMaxScaler

from sklearn.model_selection import train_test_split

from mravens_icons import *

import tensorflow as tf

from tensorflow.keras import Sequential

from tensorflow.keras.layers import Dense

import json

def one_hot(y,n):
    
    y_onehot = np.zeros((len(y),n))

    for i,j in enumerate(y):

        y_onehot[i,j]=1
        
    return y_onehot

def train_test_data(application="iris",f_sample=32,seed = 42, test_size=0.20):

    if application=="iris":

        data=load_iris()

        X,y=data['data'],data['target']  
    
    elif application=="wine":
        
        data = load_wine()

        X,y=data['data'],data['target']
        
    elif application=="breast_cancer":
        
        data=load_breast_cancer()

        X,y=data['data'],data['target']

    y_onehot = one_hot(y,np.max(y)+1)
    
    X_norm=(X-np.min(X,axis=0))/(np.max(X,axis=0)-np.min(X,axis=0))

    X_train,X_test,ytrain,ytest = train_test_split(X_norm,y,test_size=0.20,random_state=seed, stratify=y)
    
    y_train, y_test = one_hot(ytrain,np.max(y)+1), one_hot(ytest,np.max(y)+1)
    
    return X_train,X_test,y_train,y_test, ytrain,ytest

def rate_encoded_data(X,f_sample=32):
    
    X_rate = (X*f_sample).astype('int')

    X_rate_data=np.zeros((X_rate.shape[0],X_rate.shape[1],f_sample))

    for m,sample in enumerate(X_rate):

        for n,feature in enumerate(sample):

            X_rate_data[m,n,:]=np.zeros(f_sample)

            if feature>0:

                X_rate_data[m,n,0:-1:round(f_sample/feature)]=1
                
    return X_rate_data

def get_GD_based_synaptic_weights(X_train,y_train,loss='categorical_crossentropy',activation='softmax',lr=0.1,
                                  b1=0.7,b2=0.999,epochs=200, batch_size=64, verbose=1,seed=42,shuffle=False):

    tf.random.set_seed(seed)

    # Define the input shape
    input_shape = (X_train.shape[1],)  # Replace input_size with the size of your input

    # Create a Sequential model
    model = Sequential()

    initializer = tf.keras.initializers.HeNormal()

    # Add the output layer directly
    model.add(Dense(units=y_train.shape[1], input_shape=input_shape, activation=activation,use_bias=False, kernel_initializer=initializer))

    opt = tf.keras.optimizers.Adam(learning_rate=lr,beta_1=b1,beta_2=b2)

    model.compile(loss=loss, optimizer=opt, metrics=['accuracy'])

    # Train the model
    history = model.fit(X_train, y_train, epochs=epochs, batch_size=batch_size, verbose=verbose, validation_data=(X_test,y_test),shuffle=shuffle)

    keras_loss_train, keras_acc_train = model.evaluate(X_train, y_train, verbose=0)

    keras_loss_test, keras_acc_test= model.evaluate(X_test, y_test, verbose=0)

    keras_weights = model.get_weights()[0]
    
    return keras_loss_train, keras_acc_train, keras_loss_test, keras_acc_test, keras_weights

def simulate(X_rate_data,keras_weights,f_sample,st_point=[0,1,2,3],n_id =[0,1,2],
                  type_id=["output","output","output"],abs_period=[1,10,1]):

    y_pred = []
    
    spikes=[]

    for i in range(len(X_rate_data)):

        net = create_custom_network()

        net.add_stimuli(st_point,n_id,X_rate_data[i],keras_weights)

        for (i,j,k) in zip(n_id,type_id,abs_period):

            net.add_neuron(i,j)
            
            net.neuron[i].abs_period=k

        proc=MRAVENS(-5,5)

        event=process_event(f_sample,net,proc)

        event.apply_spike()

        y_pred.append(np.argmax(np.sum(event.spikes_,axis=0)))
        
        spikes.append(np.sum(event.spikes_,axis=0))
        
    return np.array(y_pred), spikes

def train_abs(X_rate_data_train,ytrain,X_rate_data_test,ytest, keras_weights,f_sample,abs_epoch,st_point=[0,1,2,3],
              n_id =[0,1,2],type_id=["output","output","output"],abs_period=np.array([5,5,5]),method="ID"):

    acc_train_list, acc_test_list, abs_period_list, spiketr_list, spikets_list = [], [], [], [], []

    for i in range(abs_epoch):

        y_pred_train, spiketr = simulate(X_rate_data_train,keras_weights,f_sample,st_point=st_point,n_id =n_id,type_id=type_id,abs_period=abs_period)

        y_pred_test, spikets = simulate(X_rate_data_test,keras_weights,f_sample,st_point=st_point,n_id =n_id,type_id=type_id,abs_period=abs_period)

        acc_train, acc_test = len(ytrain[y_pred_train==ytrain])/len(ytrain), len(ytest[y_pred_test==ytest])/len(ytest)

#         print(f"Iteration:{i+1} ::: Neuromorphic Accuracy: Train: {np.round(acc_train,3)},Test: {np.round(acc_test,3)}")

        acc_train_list.append(acc_train)

        acc_test_list.append(acc_test)

        abs_period_list.append(abs_period)
        
        spiketr_list.append(spiketr) 
        
        spikets_list.append(spikets)

#         print(f"Abs_period: {abs_period}")

        spike_dev = np.sum(one_hot(y_pred_train,y_train.shape[1])-y_train,axis=0)

#         print(f"Spike Dev: {spike_dev}")

        spike_dev_arr = np.zeros_like(spike_dev)

        idx = np.argsort(spike_dev)
        
        if method =="ID":

            spike_dev_arr[idx[0]], spike_dev_arr[idx[-1]]=  -1,1 
            
        elif method =="I":
            
            spike_dev_arr[idx[0]], spike_dev_arr[idx[-1]]=  0,1 
            
        elif method =="D":
            
            spike_dev_arr[idx[0]], spike_dev_arr[idx[-1]]=  -1,0 

        abs_period = (abs_period + spike_dev_arr).astype('int')

        abs_period[abs_period<0]=0

    acctrain, acctest, absperiod, spiketr_, spikets_ = np.array(acc_train_list), np.array(acc_test_list), np.array(abs_period_list), np.array(spiketr_list), np.array(spikets_list)

    metric = acctrain*0.50 + acctest*45 + 0.05*(1-(acctrain - acctest))  
    
    idx = np.argmax(metric)

    print(f"Best: train: {np.round(acctrain[idx],3)}, test: {np.round(acctest[idx],2)}, abs_period: {absperiod[idx]}")
    
    return acctrain, acctest, absperiod, np.round(acctrain[idx],3), np.round(acctest[idx],2), absperiod[idx], spiketr_[idx], spikets_[idx]

# %%
from sklearn.metrics import confusion_matrix

"""
Train_Test_Data
"""

# Define the file path
json_file = "config_data.json"

# Read the JSON file
with open(json_file, 'r') as file:
    data = json.load(file)

# Extract values from the data dictionary
seed = 42
f_sample = 8
abs_period_list = [[1,6,1],[3,3,3],[3,3,3]]
# abs_period_ = 3
epochs = data["epochs"]
abs_epoch = 100

app="iris"

# app_list=["iris","iris","iris"]

lr = data["lr"]
b1 = data["b1"]
b2 = data["b2"]
batch_size = data["batch_size"]

np.random.seed(seed)

tf.random.set_seed(seed)

X1, X2, X3, X4, X5, X6, X7, X8, X9 = [], [], [], [], [], [], [], [], []

Acctrain, Acctest, AbsPeriod, Spiketr_list, Spikets_list = [], [], [], [], []

conf_matrix_all=[]

# Define the file path
json_file = f"{app}_model.json"

# Read the JSON file
with open(json_file, 'r') as file:
    model_data = json.load(file)


keras_loss_train, keras_acc_train, keras_loss_test, keras_acc_test, keras_weights = model_data["keras_loss_train"], model_data["keras_acc_train"], model_data["keras_loss_test"], model_data["keras_acc_test"], np.array(model_data["keras_weights"])

"""
Rate encoded data
"""

X_rate_data_train, X_rate_data_test = rate_encoded_data(X_train,f_sample=f_sample), rate_encoded_data(X_test,f_sample=f_sample)

print(f"Keras Accuracy: Train: {np.round(keras_acc_train,3)}, Test: {np.round(keras_acc_test,3)}")

for method,abs_period  in zip(["I","D","ID"],abs_period_list): 

    X_train,X_test,y_train,y_test,ytrain,ytest=train_test_data(application=app,f_sample=f_sample,seed=seed, test_size=0.20)

    """
    Keras Weights
    """

    y_pred_train, spiketr = simulate(X_rate_data_train,keras_weights,f_sample,st_point=np.arange(X_train.shape[1]),
              n_id =np.arange(y_train.shape[1]),type_id=["output"]*y_train.shape[1],abs_period=abs_period)

    y_pred_test, spikets = simulate(X_rate_data_test,keras_weights,f_sample,st_point=np.arange(X_train.shape[1]),
              n_id =np.arange(y_train.shape[1]),type_id=["output"]*y_train.shape[1],abs_period=abs_period)

    y_all = np.concatenate((np.argmax(y_train,axis=1), np.argmax(y_test,axis=1)))

    y_pred_all = np.concatenate((y_pred_train,y_pred_test))

    conf_matrix_all.append(confusion_matrix(y_all, y_pred_all))
# Out:
# Keras Accuracy: Train: 0.833, Test: 0.867

# %%
fig, axes = plt.subplots(1, 3, figsize=(18, 6))

for i in range(3):
    im = axes[i].imshow(conf_matrix_all[i], interpolation='nearest', cmap=plt.cm.Blues)
    axes[i].set_title(f'Confusion Matrix - Fold {i+1}')
    axes[i].set_xlabel('Predicted Label')
    axes[i].set_ylabel('True Label')
    axes[i].set_xticks(np.arange(len(class_names)))
    axes[i].set_yticks(np.arange(len(class_names)))
    axes[i].set_xticklabels(class_names)
    axes[i].set_yticklabels(class_names)
    axes[i].grid(False)
    # Add colorbar after each subplot
    cbar = plt.colorbar(im, ax=axes[i])
    cbar.ax.set_ylabel('Count')

plt.tight_layout()
plt.show()

# %%
"""
Train_Test_Data
"""

# Define the file path
json_file = "config_data.json"

# Read the JSON file
with open(json_file, 'r') as file:
    data = json.load(file)

# Extract values from the data dictionary
seed = 42
f_sample = 64
abs_period_list = [[12,9], [3,2], [28,20]]
# abs_period_ = 3
epochs = data["epochs"]
abs_epoch = 100

app="iris"

# app_list=["iris","iris","iris"]

lr = data["lr"]
b1 = data["b1"]
b2 = data["b2"]
batch_size = data["batch_size"]

np.random.seed(seed)

tf.random.set_seed(seed)

X1, X2, X3, X4, X5, X6, X7, X8, X9 = [], [], [], [], [], [], [], [], []

Acctrain, Acctest, AbsPeriod, Spiketr_list, Spikets_list = [], [], [], [], []
    

for method, abs_period in zip(["I", "D", "ID"],abs_period_list):

#     method = "I"

    # for app, method, abs_period_ in zip(app_list, method_list, abs_period_list):

    X_train,X_test,y_train,y_test,ytrain,ytest=train_test_data(application=app,f_sample=f_sample,seed=seed, test_size=0.20)

    """
    Keras Weights
    """

    # Define the file path
    json_file = f"{app}_model.json"

    # Read the JSON file
    with open(json_file, 'r') as file:
        model_data = json.load(file)


    keras_loss_train, keras_acc_train, keras_loss_test, keras_acc_test, keras_weights = model_data["keras_loss_train"], model_data["keras_acc_train"], model_data["keras_loss_test"], model_data["keras_acc_test"], np.array(model_data["keras_weights"])

    """
    Rate encoded data
    """

    X_rate_data_train, X_rate_data_test = rate_encoded_data(X_train,f_sample=f_sample), rate_encoded_data(X_test,f_sample=f_sample)

    print(f"Keras Accuracy: Train: {np.round(keras_acc_train,3)}, Test: {np.round(keras_acc_test,3)}")

#     abs_period = np.ones(y_train.shape[1])*abs_period_

    y_pred_train, spiketr = simulate(X_rate_data_train,keras_weights,f_sample,st_point=np.arange(X_train.shape[1]),
              n_id =np.arange(y_train.shape[1]),type_id=["output"]*y_train.shape[1],abs_period=abs_period)

    y_pred_test, spikets = simulate(X_rate_data_test,keras_weights,f_sample,st_point=np.arange(X_train.shape[1]),
              n_id =np.arange(y_train.shape[1]),type_id=["output"]*y_train.shape[1],abs_period=abs_period)

    acc_train, acc_test = len(ytrain[y_pred_train==ytrain])/len(ytrain), len(ytest[y_pred_test==ytest])/len(ytest)
    
    print((acc_train, acc_test))

    """
    y data
    """

    yy1 = np.argmax(y_train,axis=1)

    yy2 = np.argmax(y_test,axis=1)

    yy = np.concatenate((yy1,yy2),axis=0)

    """
    Spike data
    """

    A = np.concatenate((spiketr,spikets),axis=0)


    ## y =0 for the 0, 1, 2 neuron

    data = A[yy==0][:, 0]

    X1.append(np.mean(data))

    X2.append(np.std(data))


    data = A[yy==0][:, 1]

    X1.append(np.mean(data))

    X2.append(np.std(data))


    data = A[yy==0][:, 2]

    X1.append(np.mean(data))

    X2.append(np.std(data))

    ## y =1 for the 0, 1, 2 neuron

    data = A[yy==1][:, 0]

    X1.append(np.mean(data))

    X2.append(np.std(data))


    data = A[yy==1][:, 1]

    X1.append(np.mean(data))

    X2.append(np.std(data))


    data = A[yy==1][:, 2]

    X1.append(np.mean(data))

    X2.append(np.std(data))

    ## y =2 for the 0, 1, 2 neuron

    data = A[yy==2][:, 0]

    X1.append(np.mean(data))

    X2.append(np.std(data))


    data = A[yy==2][:, 1]

    X1.append(np.mean(data))

    X2.append(np.std(data))


    data = A[yy==2][:, 2]

    X1.append(np.mean(data))

    X2.append(np.std(data))

# %%
with open("bc_64.json", "w") as file:
    json.dump({"X1":X1, "X2":X2}, file)

file.close()

# %%
import numpy as np
import matplotlib.pyplot as plt
import json

# Open the JSON file and load data
with open("iris_8.json", "r") as file:
    data = json.load(file)

spacing = 20
ss = 1

# Sample data
x11 = np.arange(1, 4)  # Generate x values for the first set of points
x12 = np.arange(4, 7) + ss  # Generate x values for the first set of points
x13 = np.arange(7, 10) + 2 * ss  # Generate x values for the first set of points

x21 = np.arange(1, 4) + spacing  # Generate x values for the first set of points
x22 = np.arange(4, 7) + ss + spacing  # Generate x values for the first set of points
x23 = np.arange(7, 10) + ss + spacing  # Generate x values for the first set of points

x31 = np.arange(1, 4) + 2 * spacing  # Generate x values for the first set of points
x32 = np.arange(4, 7) + ss + 2 * spacing  # Generate x values for the first set of points
x33 = np.arange(7, 10) + ss + 2 * spacing  # Generate x values for the first set of points

# Sample data
y = data["X1"]  # Example y-values
std_dev = data["X2"]  # Example standard deviations

plt.figure(figsize=(12, 6))

plt.rc('font', size=14, family='Calibri', weight='normal')

# Create the error bar plot for the first group
plt.errorbar(x11, y[:3], yerr=std_dev[:3], fmt='o', color='red', ecolor='red', capsize=5)
plt.errorbar(x12, y[3:6], yerr=std_dev[3:6], fmt='o', color='green', ecolor='green', capsize=5)
plt.errorbar(x13, y[6:9], yerr=std_dev[6:9], fmt='o', color='blue', ecolor='blue', capsize=5)

# Create the error bar plot for the second group
plt.errorbar(x21, y[9:12], yerr=std_dev[9:12], fmt='o', color='red', ecolor='red', capsize=5)
plt.errorbar(x22, y[12:15], yerr=std_dev[12:15], fmt='o', color='green', ecolor='green', capsize=5)
plt.errorbar(x23, y[15:18], yerr=std_dev[15:18], fmt='o', color='blue', ecolor='blue', capsize=5)

# Create the error bar plot for the third group
plt.errorbar(x31, y[18:21], yerr=std_dev[18:21], fmt='o', color='red', ecolor='red', capsize=5)
plt.errorbar(x32, y[21:24], yerr=std_dev[21:24], fmt='o', color='green', ecolor='green', capsize=5)
plt.errorbar(x33, y[24:27], yerr=std_dev[24:27], fmt='o', color='blue', ecolor='blue', capsize=5)

# Add labels and title
plt.ylabel('Average Spike per classification')

# Add method labels as x-tick labels
plt.xticks([5,25,45], ['I method', 'D method', 'ID method'])

plt.legend(["Spike when y =0", "Spike when y =1", "Spike when y =2"])

plt.savefig("iris_8.pdf",dpi=600, bbox_inches = "tight")

# Show plot
plt.show()

# %%
"""
Spike data
"""
i=1

A1 = np.array(Spiketr_list[i])

A2 = np.array(Spikets_list[i])

A = np.concatenate((A1,A2),axis=0)


## y =0 for the 0, 1, 2 neuron

data = A[yy==0][:, 0]

X4.append([np.mean(data), np.std(data)])

data = A[yy==0][:, 1]

X4.append([np.mean(data), np.std(data)])

data = A[yy==0][:, 2]

X4.append([np.mean(data), np.std(data)])

## y =1 for the 0, 1, 2 neuron

data = A[yy==1][:, 0]

X5.append([np.mean(data), np.std(data)])

data = A[yy==1][:, 1]

X5.append([np.mean(data), np.std(data)])

data = A[yy==1][:, 2]

X5.append([np.mean(data), np.std(data)])

## y =2 for the 0, 1, 2 neuron

data = A[yy==2][:, 0]

X6.append([np.mean(data), np.std(data)])

data = A[yy==2][:, 1]

X6.append([np.mean(data), np.std(data)])

data = A[yy==2][:, 2]

X6.append([np.mean(data), np.std(data)])

# %%
X4
# Out:
# [[0.56, 0.4963869458396343], [2.0, 0.0], [1.06, 0.42]]

# %%
X5
# Out:
# [[0.34, 0.47370877129308037], [2.0, 0.0], [1.68, 0.5075431016179808]]

# %%
X6
# Out:
# [[0.34, 0.47370877129308037], [2.0, 0.0], [1.68, 0.5075431016179808]]

# %%
plt.figure(figsize=(10,8))

plt.plot(Acctrain[0][:18],"-r")

plt.plot(Acctrain[1][:25], "-g")

plt.plot(Acctrain[2][:9],"-b")

plt.ylim([0.6,0.95])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-328-137a37a185b3> in <module>
#       3 plt.plot(Acctrain[0][:18],"-r")
#       4
# ----> 5 plt.plot(Acctrain[1][:25], "-g")
#       6
#       7 plt.plot(Acctrain[2][:9],"-b")
#
# IndexError: list index out of range

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(12,8))

plt.plot(Acctrain[0], "-r", label="Model 1")
plt.plot(Acctrain[1], "-g", label="Model 2")
plt.plot(Acctrain[2], "-b", label="Model 3")

plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Training Accuracy", fontsize=14)
plt.title("Training Accuracy Comparison", fontsize=16)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend()
plt.ylim([0.4,1])

plt.show()

# %%
Best = []

max_acc = 0

for i in Acctrain[0]:
    
    if i>max_acc:
        
        max_acc = i;
        
    Best.append(max_acc)
    
    
Best1 = []

max_acc = 0

for i in Acctrain[1]:
    
    if i>max_acc:
        
        max_acc = i;
        
    Best1.append(max_acc)
    
Best2 = []

max_acc = 0

for i in Acctrain[2]:
    
    if i>max_acc:
        
        max_acc = i;
        
    Best2.append(max_acc)

# %%
plt.figure(figsize=(8,6))

plt.plot(Acctrain[0][:20], "--r", label="I(Temp Model)")
plt.plot(Best[:20], "-r", label="I(Updated Model)")
plt.plot(Acctrain[1][:20], "--g", label="D(Temp Model)")
plt.plot(Best1[:20], "-g", label="D(Updated Model)")
plt.plot(Acctrain[2][:20], "--b", label="ID(Temp Model)")
plt.plot(Best2[:20], "-b", label="ID(Updated Model)")

plt.xlabel("Epochs", fontsize=14)
plt.ylabel("Training Accuracy", fontsize=14)
plt.xticks(range(0, 20, 5), fontsize=12)
plt.yticks(fontsize=12)
plt.legend()

plt.show()

# %%
plt.figure(figsize=(10,8))
plt.plot(Best[:30], label='Best')
plt.plot(Best1[:30], label='Best1')
plt.plot(Best2[:30], label='Best2')
plt.ylim([0.4, 1])
plt.xticks(range(0, 31, 5))  # Set x-axis ticks from 0 to 20 with step size 5
plt.legend()
plt.show()
